# %% [markdown]
# # PARAMETER IDENTIFICATION NOTEBOOK
#
# In this notebook we leverage the pretrained surrogate models to identify the generating transmissivity fiels.\
# We start from noisy signals. The noise is an additive white noise, manually added to the data to emulate experimental data.

# %% [markdown]
# ##### Importing necessary libraries

# %%
# Standard library imports
import sys

import os
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['KERAS_BACKEND'] = 'tensorflow'

# Third-party library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import arviz as az
import timeit

import scipy.stats as stats
from keras.models import Sequential
from keras.layers import Dense, Concatenate
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model

#Try with TinyDA
import tinyDA as tda
from scipy.stats import multivariate_normal
from scipy.stats import uniform


# Local module imports
sys.path.append('./src/SurrogateModeling')
sys.path.append('./src/InverseProblems')
sys.path.append('./src/utils')
from utils import * 
from plotting import *
from random_process import *
# Out:
# 2024-07-28 17:41:42.572481: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Ray module not found. Multiprocessing features are not available

# %% [markdown]
# #### Decide sample to use for experimental data

# %%
sample = 16 # Which sample of the training set do wou want to take as experimental input?
OUTPUT_FILENAME = "./samples/sample_coarse_"+str(sample)

# %% [markdown]
# #### Set Bayesian Identification Parameters

# %%
# Noise Configuration
noise = 0.001

# %% [markdown]
# #### Load Surrogate Models

# %%
# Extract test data for visualization or further processing
n_eig = 64
X_values = np.loadtxt('./data/X_test_64000.csv', delimiter = ',')
y_values = np.loadtxt('./data/y_test_64000.csv',delimiter = ',')

# %%
model_c = Sequential()

# Add layers to the model
model_c.add(Dense(128, input_shape=(64,), activation='gelu'))
model_c.add(Dense(64, activation='gelu'))
model_c.add(Dense(25, activation='exponential'))

model_c = load_model('./models3/model_LF_16000_2.keras')
# Out:
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
def model_lf(input):
    return np.array(model_c(input.reshape(1,64))).reshape(25)

# %%
model_f = Sequential()

model_f.add(Dense(256, input_shape=(89,), activation='gelu'))
model_f.add(Dense(128, activation='gelu'))
model_f.add(Dense(64, activation='gelu'))
model_f.add(Dense(25, activation='exponential'))

model_f = load_model('./models3/model_HF_16000_1.keras')

# %%
def model_hf (input):
    input = input.reshape(1,64)
    input_fine = np.hstack((input, model_c(input) )).reshape(1,89)
    return np.array(model_f(input_fine)).reshape(25)

# %% [markdown]
# ### Define Prior, likelyhood and proposal

# %%
# Select a true sample for testing
x_true, y_true = X_values[sample], y_values[sample]
# Generate observed data by adding Gaussian noise to the true data
y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# Define the prior distribution for the input parameters
x_distribution = stats.multivariate_normal(mean = np.zeros(n_eig), cov = np.eye(n_eig))

# set the likelihood
cov_likelihood = noise * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)  
y_distribution_fine = tda.GaussianLogLike(y_observed, cov_likelihood)

# %%
x_true
# Out:
# array([ 1.1537516 ,  1.59930096,  1.0712466 ,  0.16285143, -1.77693013,
#         1.13429878, -0.93495814,  2.69019167,  0.62724265,  2.43673345,
#        -0.56867574, -0.14274359, -2.2278197 , -0.75301225, -1.62102912,
#         1.00922652,  1.91294232, -0.85850774, -2.31511961,  2.52755889,
#         0.09154126, -0.29053499, -0.53602897,  0.34754535, -0.01173919,
#         1.17243121, -1.22188369, -0.96913818, -0.39950806,  1.01188892,
#        -1.20621682, -0.87489908,  0.57811353, -0.52530346, -1.09333604,
#         1.10048611,  0.91836686,  1.14180672,  0.48037021,  1.52078407,
#         1.50176772,  0.74254826,  0.04931592, -0.34914246,  1.8694958 ,
#         1.63233869, -1.17102144,  1.14337158,  0.92133669,  0.30800992,
#        -0.87071644, -0.604474  ,  0.22870254,  0.15959755,  0.5696756 ,
#        -0.17067527,  0.27926433, -1.32688715,  0.87618644,  0.16703566,
#        -0.26100612,  0.29748849,  1.39345466, -0.99058778])

# %% [markdown]
# #### Perform least square optimization for each starting point

# %%
# Initialize a list to hold the optimized parameters for each start point
initial_guesses = []

# Display the true parameters for reference
print("Real Params: ", x_true)

bounds = (-3*np.ones(n_eig), 3*np.ones(n_eig))

# Iterate over each parameter start point to perform optimizatio
# Perform least squares optimization given the observed data, forward model,
# start point, and parameter bounds
optimized_params, covariance_matrix = least_squares_optimization(
        y_observed=y_observed, 
        forward_model=model_lf , 
        start_point=np.zeros(n_eig), 
        bounds=bounds,
        l2_coeff = 0#1e-6
    )

# Append the optimized parameters to the list of initial guesses
initial_guesses.append(optimized_params)

# Print the optimized parameters for this iteration
print(f"Optimized Params : {optimized_params}")
# Out:
# Real Params:  [ 1.1537516   1.59930096  1.0712466   0.16285143 -1.77693013  1.13429878
#  -0.93495814  2.69019167  0.62724265  2.43673345 -0.56867574 -0.14274359
#  -2.2278197  -0.75301225 -1.62102912  1.00922652  1.91294232 -0.85850774
#  -2.31511961  2.52755889  0.09154126 -0.29053499 -0.53602897  0.34754535
#  -0.01173919  1.17243121 -1.22188369 -0.96913818 -0.39950806  1.01188892
#  -1.20621682 -0.87489908  0.57811353 -0.52530346 -1.09333604  1.10048611
#   0.91836686  1.14180672  0.48037021  1.52078407  1.50176772  0.74254826
#   0.04931592 -0.34914246  1.8694958   1.63233869 -1.17102144  1.14337158
#   0.92133669  0.30800992 -0.87071644 -0.604474    0.22870254  0.15959755
#   0.5696756  -0.17067527  0.27926433 -1.32688715  0.87618644  0.16703566
#  -0.26100612  0.29748849  1.39345466 -0.99058778]
# Optimized Params : [ 0.39736546  0.87996631  0.98753333  0.0441518  -2.1378683   0.91206262
#  -1.35923488  1.41795564  1.40087382  1.49527747  0.16692484 -0.11250617
#  -0.8986329  -0.32804618 -0.29672664 -0.55709603  0.53621773 -0.99809415
#  -1.61808009  1.92688269 -0.05117699 -0.41559422 -2.67396733  0.29588963
#  -0.38393643  1.23787374 -1.07383921 -0.60024095  0.31044176 -0.17543075
#  -0.37055775 -1.24220853 -0.55813479 -1.39878387  0.24378777  1.48558283
#   0.7555428   0.10847271 -0.16946381  0.80697421  1.46686238 -0.09118623
#   2.27578675 -1.79247053  1.09346916 -0.10706864  1.30643946 -0.065504
#  -0.68352111  1.15238735  1.75123284  0.11140917 -0.2106779   0.66809255
#   1.44794821  0.2528811   0.28269002  0.48843512 -1.55986073 -0.57351646
#   0.13224646  1.3719412  -0.66680384 -0.28821896]

# %% [markdown]
# #### Do Metropolis Hastings Sampling

# %% [markdown]
# Set the parameters for the algorithm

# %%
scaling = 0.1
n_iter =  28000 #55000
burnin = 3000 #5000
thin = 25
sub_sampling = 2

# %%
#cov = np.diag(np.linspace(1,5,n_eig))
cov = np.eye(n_eig)

# %%
# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine  = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [ my_posterior_coarse, my_posterior_fine ]
# random walk Metropolis
#my_proposal = tda.GaussianRandomWalk(C=covariance_matrix*1e-19, scaling= scaling)
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)
#my_proposal = tda.AdaptiveMetropolis(C0=np.eye(n_eig), sd = 0.2)

# %%
# Initialize a list to hold the Markov chain samples for each initial guess
samples_mh = []
ESS_values = []

# Iterate over each initial guess to set up and run the Markov chain sampler
start_0 = timeit.default_timer() 
for index, initial_guess in enumerate(initial_guesses):
    samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), adaptive_error_model='state-independent')
    idata = tda.to_inference_data(samples, level='fine')
    # Remove the burnin and sub-sample
    idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
    # Append the samples to the list
    samples_mh.append(idata)
    ess = az.ess(idata)
    # Compute and print the Effective Sample Size (ESS) of the first set of samples
    print("Effective Sample Size: ", ess,"\n\n\n")
end_0 = timeit.default_timer() 

# Computing diagnostics and collecting results
#print("\nRhat: ", az.rhat(az.concat(samples_mh, dim = 'chain')))

#print('Mean ESS:' , np.mean(ESS_values, axis = 0))
#print('Time/ESS MDA',(end_0-start_0)/(5*np.mean(ESS_values, axis = 0)) )
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.440, α_f = 0.35: 100%|██████████| 28000/28000 [02:51<00:00, 163.64it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Effective Sample Size:  <xarray.Dataset> Size: 512B
# Dimensions:  ()
# Data variables: (12/64)
#     x0       float64 8B 35.62
#     x1       float64 8B 43.81
#     x2       float64 8B 57.81
#     x3       float64 8B 41.91
#     x4       float64 8B 26.46
#     x5       float64 8B 28.45
#     ...       ...
#     x58      float64 8B 10.17
#     x59      float64 8B 8.924
#     x60      float64 8B 27.24
#     x61      float64 8B 14.87
#     x62      float64 8B 11.77
#     x63      float64 8B 28.77

# %% [markdown]
# Let's look at the trace plot of one chain

# %% [markdown]
# # Diagnostics

# %%
# Plot trace of the first set of samples
az.plot_trace(idata, var_names=['x0', 'x2', 'x3','x4','x5'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's compare the prediction of the mean parameter combination and the experimental signal

# %%
# Plotting and data collection
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_results( y_true, y_observed, model_hf, data, n_eig,x_true)

# %% [markdown]
# Finally, let's look at the parameters distribution

# %%
keys = ['x'+ str(i) for i in range(64)]
plot_parameter_distributions(data, x_true, keys, n_eig)

# %% [markdown]
# ### Reconstructed field

# %%
plot_fields(x_true=x_true, x_estimated=data.mean(axis=0),n_eig=n_eig, lognormal=False)

# %% [markdown]
# # DIFFERENT PARAMETERS

# %% [markdown]
# ### Lower likelyhood

# %%
noise = 0.001
scaling = 0.04
n_iter =  30000 #55000
burnin = 5000 #5000
thin = 20
sub_sampling = 1


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = noise * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood*0.1)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood*0.1)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

# RUN THE MCMC
samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
idata = tda.to_inference_data(samples, level='fine')
# Remove the burnin and sub-sample
idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
ess = az.ess(idata)
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ess,"\n\n\n")
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.530, α_f = 0.38: 100%|██████████| 30000/30000 [03:00<00:00, 165.99it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Effective Sample Size:  <xarray.Dataset> Size: 512B
# Dimensions:  ()
# Data variables: (12/64)
#     x0       float64 8B 13.89
#     x1       float64 8B 7.789
#     x2       float64 8B 6.855
#     x3       float64 8B 9.299
#     x4       float64 8B 11.66
#     x5       float64 8B 8.791
#     ...       ...
#     x58      float64 8B 8.272
#     x59      float64 8B 5.299
#     x60      float64 8B 14.7
#     x61      float64 8B 10.5
#     x62      float64 8B 9.137
#     x63      float64 8B 7.409

# %%
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_fields(x_true=x_true, x_estimated=data.mean(axis=0),n_eig=n_eig, lognormal=False)

# %% [markdown]
# ### Higher Noise

# %%
noise = 0.01
scaling = 0.05
n_iter =  30000 #55000
burnin = 5000 #5000
thin = 20
sub_sampling = 2


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = noise**2 * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

# RUN THE MCMC
samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
idata = tda.to_inference_data(samples, level='fine')
# Remove the burnin and sub-sample
idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
ess = az.ess(idata)
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ess,"\n\n\n")
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.395, α_f = 0.15: 100%|██████████| 30000/30000 [05:08<00:00, 97.17it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Effective Sample Size:  <xarray.Dataset> Size: 512B
# Dimensions:  ()
# Data variables: (12/64)
#     x0       float64 8B 7.534
#     x1       float64 8B 1.587
#     x2       float64 8B 2.069
#     x3       float64 8B 13.35
#     x4       float64 8B 12.99
#     x5       float64 8B 4.357
#     ...       ...
#     x58      float64 8B 9.665
#     x59      float64 8B 17.84
#     x60      float64 8B 5.346
#     x61      float64 8B 3.31
#     x62      float64 8B 7.117
#     x63      float64 8B 1.411

# %%
e = [ess.data_vars['x'+str(i)].values for i in range(64)]
np.mean(e)
# Out:
# 9.69524060972925

# %%
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_fields(x_true=x_true, x_estimated=data.mean(axis=0),n_eig=n_eig, lognormal=False)

# %% [markdown]
# ### No noise

# %%
noise = 0.00
scaling = 0.05
n_iter =  30000 #55000
burnin = 5000 #5000
thin = 20
sub_sampling = 1


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = 0.01**2 * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

# RUN THE MCMC
samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
idata = tda.to_inference_data(samples, level='fine')
# Remove the burnin and sub-sample
idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
ess = az.ess(idata)
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ess,"\n\n\n")
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.300, α_f = 0.15:  62%|██████▏   | 18505/30000 [01:51<01:09, 165.48it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 23
#      20 my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)
#      22 # RUN THE MCMC
# ---> 23 samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
#      24 idata = tda.to_inference_data(samples, level='fine')
#      25 # Remove the burnin and sub-sample
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/sampler.py:216, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     213 elif n_levels == 2:
#     214     # sequential sampling.
#     215     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 216         samples = _sample_sequential_da(
#     217             posteriors,
#     218             proposal,
#     219             iterations,
#     220             n_chains,
#     221             initial_parameters,
#     222             subsampling_rate,
#     223             adaptive_error_model,
#     224             store_coarse_chain,
#     225         )
#     226     # parallel sampling.
#     227     else:
#     228         samples = _sample_parallel_da(
#     229             posteriors,
#     230             proposal,
#    (...)
#     237             force_progress_bar,
#     238         )
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/sampler.py:342, in _sample_sequential_da(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain)
#     330     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     331     chains.append(
#     332         DAChain(
#     333             posteriors[0],
#    (...)
#     340         )
#     341     )
# --> 342     chains[i].sample(iterations)
#     344 info = {
#     345     "sampler": "DA",
#     346     "n_chains": n_chains,
#     347     "iterations": iterations + 1,
#     348     "subsampling_rate": subsampling_rate,
#     349 }
#     351 # collect the coarse samples.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/chain.py:322, in DAChain.sample(self, iterations, progressbar)
#     312     pbar.set_description(
#     313         "Running chain, \u03B1_c = {0:.3f}, \u03B1_f = {1:.2f}".format(
#     314             np.mean(
#    (...)
#     318         )
#     319     )
#     321 # run the coarse chain.
# --> 322 self._sample_coarse()
#     324 # if nothing was accepted on the coarse, repeat the previous sample.
#     325 if sum(self.accepted_coarse[-self.subsampling_rate :]) == 0:
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/chain.py:384, in DAChain._sample_coarse(self)
#     381 proposal = self.proposal.make_proposal(self.chain_coarse[-1])
#     383 # create a link from that proposal.
# --> 384 proposal_link_coarse = self.posterior_coarse.create_link(proposal)
#     386 # compute the acceptance probability, which is unique to
#     387 # the proposal.
#     388 alpha_1 = self.proposal.get_acceptance(
#     389     proposal_link_coarse, self.chain_coarse[-1]
#     390 )
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# Cell In[7], line 2, in model_lf(input)
#       1 def model_lf(input):
# ----> 2     return np.array(model_c(input.reshape(1,64))).reshape(25)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/sequential.py:209, in Sequential.call(self, inputs, training, mask)
#     207 def call(self, inputs, training=None, mask=None):
#     208     if self._functional:
# --> 209         return self._functional.call(inputs, training=training, mask=mask)
#     211     # Fallback: Just apply the layer sequence.
#     212     # This typically happens if `inputs` is a nested struct.
#     213     for layer in self.layers:
#     214         # During each iteration, `inputs` are the inputs to `layer`, and
#     215         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     216         # end of each iteration `inputs` is set to `outputs` to prepare for
#     217         # the next layer.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/layer.py:766, in Layer.__call__(self, *args, **kwargs)
#     761 call_spec = CallSpec(self._call_signature, args, kwargs)
#     763 ############################################
#     764 # 3. Check input spec for 1st positional arg.
#     765 # TODO: consider extending this to all args and kwargs.
# --> 766 self._assert_input_compatibility(call_spec.first_arg)
#     768 ################
#     769 # 4. Call build
#     770 with self._open_name_scope():
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/layer.py:1369, in Layer._assert_input_compatibility(self, arg_0)
#    1367 def _assert_input_compatibility(self, arg_0):
#    1368     if self.input_spec:
# -> 1369         input_spec.assert_input_compatibility(
#    1370             self.input_spec, arg_0, layer_name=self.name
#    1371         )
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/input_spec.py:181, in assert_input_compatibility(input_spec, inputs, layer_name)
#     178 if spec is None:
#     179     continue
# --> 181 shape = backend.standardize_shape(x.shape)
#     182 ndim = len(shape)
#     183 # Check ndim.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/backend/common/variables.py:532, in standardize_shape(shape)
#     530     raise ValueError(f"Cannot convert '{shape}' to a shape.")
#     531 if config.backend() == "tensorflow":
# --> 532     if isinstance(shape, tf.TensorShape):
#     533         # `tf.TensorShape` may contain `Dimension` objects.
#     534         # We need to convert the items in it to either int or `None`
#     535         shape = shape.as_list()
#     536 shape = tuple(shape)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/module_utils.py:31, in LazyModule.__getattr__(self, name)
#      25     except ImportError:
#      26         raise ImportError(
#      27             f"This requires the {self.name} module. "
#      28             f"You can install it via `pip install {self.pip_name}`"
#      29         )
# ---> 31 def __getattr__(self, name):
#      32     if name == "_api_export_path":
#      33         raise AttributeError
#
# KeyboardInterrupt:

# %%
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_fields(x_true=x_true, x_estimated=data.mean(axis=0),n_eig=n_eig, lognormal=False)

# %% [markdown]
# ### True likelyhood

# %%
noise = 0.001
scaling = 0.007
n_iter =  30000 #55000
burnin = 5000 #5000
thin = 20
sub_sampling = 1


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = noise**2 * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

# RUN THE MCMC
samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
idata = tda.to_inference_data(samples, level='fine')
# Remove the burnin and sub-sample
idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
ess = az.ess(idata)
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ess,"\n\n\n")
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.210, α_f = 0.10: 100%|██████████| 30000/30000 [02:47<00:00, 178.82it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Effective Sample Size:  <xarray.Dataset> Size: 512B
# Dimensions:  ()
# Data variables: (12/64)
#     x0       float64 8B 1.746
#     x1       float64 8B 1.461
#     x2       float64 8B 6.308
#     x3       float64 8B 10.11
#     x4       float64 8B 12.91
#     x5       float64 8B 6.477
#     ...       ...
#     x58      float64 8B 6.043
#     x59      float64 8B 1.319
#     x60      float64 8B 6.161
#     x61      float64 8B 6.649
#     x62      float64 8B 2.452
#     x63      float64 8B 1.321

# %%
e = [ess.data_vars['x'+str(i)].values for i in range(64)]
np.mean(e)
# Out:
# 3.5057760263661493

# %%
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_fields(x_true=x_true, x_estimated=data.mean(axis=0),n_eig=n_eig, lognormal=False)

# %%
# Plotting and data collection
data = tda.get_samples(samples)['chain_0'][burnin:n_iter:thin, :]
plot_results( y_true, y_observed, model_nn, data, n_eig,x_true)

# %% [markdown]
# ### Parameter tuning

# %%
noise = 0.01
scaling = 0.05
n_iter =  30000 #55000
burnin = 3000 #5000
thin = 20
sub_sampling = 1


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = noise**2 * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

ESS_values = []
times = []
# RUN THE MCMC
for i in range(3): 
    start = timeit.default_timer()
    samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
    end = timeit.default_timer()
    idata = tda.to_inference_data(samples, level='fine')
    # Remove the burnin and sub-sample
    idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
    # Save executing time 
    times.append(end-start)
    ess = az.ess(idata)  
    e = [ess.data_vars['x'+str(i)].values for i in range(64)]
    ESS_values.append(np.mean(e))
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ESS_values)
print("Computing times:       ", times )
print("Average Time/ESS       ", np.mean(times)/np.mean(ESS_values))
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.280, α_f = 0.18: 100%|██████████| 30000/30000 [02:46<00:00, 180.03it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Sampling chain 1/1
# Running chain, α_c = 0.240, α_f = 0.16: 100%|██████████| 30000/30000 [02:46<00:00, 180.07it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Sampling chain 1/1
# Running chain, α_c = 0.350, α_f = 0.27: 100%|██████████| 30000/30000 [02:45<00:00, 181.27it/s]
# /Users/lucacaroselli/miniconda3/envs/fenics/lib/python3.11/site-packages/arviz/data/inference_data.py:157: UserWarning: qoi group is not defined in the InferenceData scheme
#   warnings.warn(
# Effective Sample Size:  [8.109070508085704, 8.550349913910646, 7.62245499847879]
# Computing times:        [166.8508864579926, 166.70992824999848, 165.57192595800734]
# Average Time/ESS        20.555773885781328

# %%
noise = 0.01
scaling = 0.05
n_iter =  30000 #55000
burnin = 3000 #5000
thin = 20
sub_sampling = 2


y_observed = y_true + np.random.normal(scale=noise,size=y_true.shape[0])

# LIKELYHOOD
cov_likelihood = noise**2 * np.eye(25)
y_distribution_coarse = tda.AdaptiveGaussianLogLike(y_observed, cov_likelihood)
y_distribution_fine  = tda.GaussianLogLike(y_observed, cov_likelihood)

# initialise the LinkFactory
my_posterior_coarse = tda.Posterior(x_distribution, y_distribution_coarse, model_lf)
my_posterior_fine = tda.Posterior(x_distribution, y_distribution_fine, model_hf)
my_posteriors = [my_posterior_coarse, my_posterior_fine]
my_proposal = tda.CrankNicolson(scaling=scaling, adaptive=False, gamma = 1.01, period=100)

ESS_values = []
times = []
# RUN THE MCMC
for i in range(3): 
    start = timeit.default_timer()
    samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
    end = timeit.default_timer()
    idata = tda.to_inference_data(samples, level='fine')
    # Remove the burnin and sub-sample
    idata = idata.sel(draw=slice(burnin, None, thin), groups="posterior")
    # Save executing time 
    times.append(end-start)
    ess = az.ess(idata)  
    e = [ess.data_vars['x'+str(i)].values for i in range(64)]
    ESS_values.append(np.mean(e))
# Compute and print the Effective Sample Size (ESS) of the first set of samples
print("Effective Sample Size: ", ESS_values)
print("Computing times:       ", times )
print("Average Time/ESS       ", np.mean(times)/np.mean(ESS_values))
# Out:
# Sampling chain 1/1
# Running chain, α_c = 0.400, α_f = 0.19:  52%|█████▏    | 15454/30000 [03:40<03:27, 70.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 27
#      25 for i in range(3):
#      26     start = timeit.default_timer()
# ---> 27     samples = tda.sample(my_posteriors, my_proposal, iterations=n_iter, n_chains=1, initial_parameters=np.zeros(64), subsampling_rate= sub_sampling, adaptive_error_model='state-independent')
#      28     end = timeit.default_timer()
#      29     idata = tda.to_inference_data(samples, level='fine')
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/sampler.py:216, in sample(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain, force_sequential, force_progress_bar)
#     213 elif n_levels == 2:
#     214     # sequential sampling.
#     215     if not ray_is_available or n_chains == 1 or force_sequential:
# --> 216         samples = _sample_sequential_da(
#     217             posteriors,
#     218             proposal,
#     219             iterations,
#     220             n_chains,
#     221             initial_parameters,
#     222             subsampling_rate,
#     223             adaptive_error_model,
#     224             store_coarse_chain,
#     225         )
#     226     # parallel sampling.
#     227     else:
#     228         samples = _sample_parallel_da(
#     229             posteriors,
#     230             proposal,
#    (...)
#     237             force_progress_bar,
#     238         )
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/sampler.py:342, in _sample_sequential_da(posteriors, proposal, iterations, n_chains, initial_parameters, subsampling_rate, adaptive_error_model, store_coarse_chain)
#     330     print("Sampling chain {}/{}".format(i + 1, n_chains))
#     331     chains.append(
#     332         DAChain(
#     333             posteriors[0],
#    (...)
#     340         )
#     341     )
# --> 342     chains[i].sample(iterations)
#     344 info = {
#     345     "sampler": "DA",
#     346     "n_chains": n_chains,
#     347     "iterations": iterations + 1,
#     348     "subsampling_rate": subsampling_rate,
#     349 }
#     351 # collect the coarse samples.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/chain.py:337, in DAChain.sample(self, iterations, progressbar)
#     332     self.is_coarse.append(False)
#     334 else:
#     335     # when subsampling is complete, create a new fine link from the
#     336     # previous coarse link.
# --> 337     proposal_link_fine = self.posterior_fine.create_link(
#     338         self.chain_coarse[-1].parameters
#     339     )
#     341     # compute the delayed acceptance probability.
#     342     if self.adaptive_error_model == "state-dependent":
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tinyDA/posterior.py:95, in Posterior.create_link(self, parameters)
#      92 prior = self.prior.logpdf(parameters)
#      94 # get the model output and the qoi.
# ---> 95 model_output = self.model(parameters)
#      97 # extract model output and qoi.
#      98 if isinstance(model_output, tuple):
#
# Cell In[9], line 4, in model_hf(input)
#       2 input = input.reshape(1,64)
#       3 input_fine = np.hstack((input, model_c(input) )).reshape(1,89)
# ----> 4 return np.array(model_f(input_fine)).reshape(25)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/sequential.py:209, in Sequential.call(self, inputs, training, mask)
#     207 def call(self, inputs, training=None, mask=None):
#     208     if self._functional:
# --> 209         return self._functional.call(inputs, training=training, mask=mask)
#     211     # Fallback: Just apply the layer sequence.
#     212     # This typically happens if `inputs` is a nested struct.
#     213     for layer in self.layers:
#     214         # During each iteration, `inputs` are the inputs to `layer`, and
#     215         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     216         # end of each iteration `inputs` is set to `outputs` to prepare for
#     217         # the next layer.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/models/functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/layers/core/dense.py:154, in Dense.call(self, inputs)
#     152     x = ops.add(x, self.bias)
#     153 if self.activation is not None:
# --> 154     x = self.activation(x)
#     155 return x
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/activations/activations.py:300, in gelu(x, approximate)
#     280 @keras_export("keras.activations.gelu")
#     281 def gelu(x, approximate=False):
#     282     """Gaussian error linear unit (GELU) activation function.
#     283
#     284     The Gaussian error linear unit (GELU) is defined as:
#    (...)
#     298     - [Hendrycks et al., 2016](https://arxiv.org/abs/1606.08415)
#     299     """
# --> 300     return ops.gelu(x, approximate=approximate)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/ops/nn.py:498, in gelu(x, approximate)
#     496 if any_symbolic_tensors((x,)):
#     497     return Gelu(approximate).symbolic_call(x)
# --> 498 return backend.nn.gelu(x, approximate)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py:76, in gelu(x, approximate)
#      74 def gelu(x, approximate=True):
#      75     x = convert_to_tensor(x)
# ---> 76     return tf.nn.gelu(x, approximate=approximate)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/ops/nn_ops.py:3752, in gelu(features, approximate, name)
#    3748   return 0.5 * features * (
#    3749       1.0 + math_ops.tanh(0.7978845608028654 *
#    3750                           (features + coeff * math_ops.pow(features, 3))))
#    3751 else:
# -> 3752   return 0.5 * features * (1.0 + math_ops.erf(
#    3753       features / math_ops.cast(1.4142135623730951, features.dtype)))
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/framework/override_binary_operator.py:107, in override_binary_operator_helper.<locals>.binary_op_wrapper(x, y)
#     105 @traceback_utils.filter_traceback
#     106 def binary_op_wrapper(x, y):
# --> 107   with ops.name_scope(None, op_name, [x, y]) as name:
#     108     try:
#     109       # force_same_dtype=False to preserve existing TF behavior
#     110       # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111       #   r_binary_op_wrapper use different force_same_dtype values.
#     112       x, y = maybe_promote_tensors(x, y)
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:5524, in name_scope(name, default_name, values, skip_on_eager)
#    5521   return internal_name_scope_v1(name, default_name, values)
#    5523 if skip_on_eager:
# -> 5524   return NullContextmanager()
#    5526 name = default_name if name is None else name
#    5527 if values:
#    5528   # The presence of a graph tensor in `values` overrides the context.
#    5529   # TODO(slebedev): this is Keras-specific and should be removed.
#
# File ~/miniconda3/envs/fenics/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:176, in NullContextmanager.__init__(self, *args, **kwargs)
#     174 class NullContextmanager(contextlib.AbstractContextManager[None]):
# --> 176   def __init__(self, *args, **kwargs) -> None:
#     177     pass
#     179   def __enter__(self) -> None:
#
# KeyboardInterrupt:
