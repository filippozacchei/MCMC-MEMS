# %% [markdown]
# <a href="https://colab.research.google.com/github/ContiPaolo/Multifidelity-Tutorial/blob/main/MF_POD_Burger's1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Multi-fidelity reduced-order modeling on Groundwater's flow - Darcy equation**

# %% [markdown]
# #### We aim to create a reduced-order surrogate model that enables the efficient recovery of high-fidelities solutions parameter variations, starting from their low-fidelity counterparts.
#
# #### We consider a data-driven strategy that combines a coarser FEM solver with multi-fidelity neural network surrogates.

# %% [markdown]
# #### Import libraries

# %%
import numpy as np
#import matplotlib as plt
from matplotlib import pyplot as plt
import pandas as pd 
import tensorflow as tf
from tensorflow.keras.optimizers import Adam,Nadam,Adamax
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import load_model
from sklearn.utils import extmath
from tensorflow.keras.regularizers import l2

from sklearn.model_selection import KFold


#######################     CONFIGURATIONS     ##########################
seed = 29
train = True
save = True

# %% [markdown]
# # DATASET
# The dataset has been developed using fenics library, it is composed of 64000 samples divided in 90% training and 10% testing.\
# The input (or X) are the 64 first component of the Karhunen-Loève (KL) decompositions. \
# These eigenmodes allow to paratetrize a random field in the most accurate way.

# %% [markdown]
# The output: 25 sensors are used to record the hydraulic pressure in the domain $\Omega$ \
# The sensors are distributed on a grid with positions [0.1, 0.3, 0.5, 0.7, 0.9]

# %% [markdown]
# Training Multi Fidelity connected neural network surrogate model

# %% [markdown]
# #### Additional resolution 25-25

# %% [markdown]
# Note to self: NN with two initial branches. \
# Branch 1 takes in input the parameters, followed by a 6 Hiddel Layer NN\
# Branch 2 takes in input the Lf solution obtained by model_25resolution_64000\
# both branches added anbd used as input for a single Hidden layer

# %%
import numpy as np
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Add
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

Training = False

coeff = 1e-9
n_neurons = 256
n_splits = 4
n_sample = 64000

model_lf = load_model(f'./models/model_25resolution_64000samples_1_coeff1e-09.keras')

# Load the data
X_train_params = np.loadtxt('../../data/50-25-10/X_train_50resolution.csv', delimiter=',')[:n_sample,:]
X_train_pod = model_lf(X_train_params).numpy()[:n_sample,:]
y_train = np.loadtxt('../../data/50-25-10/y_train_50resolution.csv', delimiter=',')[:n_sample,:]

print(np.mean((X_train_pod - y_train)**2))

print(y_train)

X_test_params = np.loadtxt('../../data/50-25-10/X_test_50resolution.csv', delimiter=',')
X_test_pod = model_lf(X_test_params).numpy()
y_test = np.loadtxt('../../data/50-25-10/y_test_50resolution.csv', delimiter=',')

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch > 1000:
        return lr*(epoch)/(1+epoch)
    else:
        return max(lr * 0.995, 1e-7)
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 2

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(combined)
output = Dense(25, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

if Training:
    for train_index, val_index in kf.split(X_train_params):

        print(f"Training fold {fold_var}...")

        # Splitting the data into training and validation sets
        X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
        X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
        y_train_k, y_val_k = y_train[train_index], y_train[val_index]

        # Compile the model
        initial_learning_rate = 0.001
        optimizer = Adam(learning_rate=initial_learning_rate)
        model.compile(optimizer='adam',
                loss='mean_squared_error',
                metrics=['mean_squared_error'])

        # Define the learning rate scheduler callback
        lr_scheduler = LearningRateScheduler(scheduler)

        # Train the model
        history = model.fit([X_train_params_k, X_train_pod_k], y_train_k,
                            epochs=1000,
                            batch_size=64,
                            validation_data=([X_val_params_k, X_val_pod_k], y_val_k),
                            validation_freq=10,
                            callbacks=[lr_scheduler])
        
        # Save the model for each fold
        model.save(f'./models/model_2step_50-25resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

        # Increment the fold number
        fold_var += 1
# Out:
# 2.166197124468869e-05
# [[0.78230312 0.84320135 0.90730646 ... 0.10152712 0.12054176 0.1157965 ]
#  [0.86937181 0.91817199 0.90050137 ... 0.08265604 0.07350862 0.0869059 ]
#  [0.87029133 0.86992623 0.8807646  ... 0.16774914 0.1157032  0.03191426]
#  ...
#  [0.9388186  0.96637925 0.98177631 ... 0.13355211 0.10614992 0.10202759]
#  [0.98489767 0.97786013 0.94828756 ... 0.0951684  0.08617375 0.1131967 ]
#  [0.92745259 0.88263388 0.88210368 ... 0.22664863 0.08917434 0.03076565]]

# %%
n_sample = 16000
n_splits = 4
coeff = 1e-8

n_splits = 4
mse_train = np.zeros((n_splits,1))
mse_test = np.zeros((n_splits,1))
rmse_train = np.zeros((n_splits,1))
rmse_test = np.zeros((n_splits,1))

fold_var = 1

for train_index, val_index in kf.split(X_train_params):
    print(f"Training fold {fold_var}...")

    # Splitting the data into training and validation sets
    X_train_k, X_val_k = X_train_params[train_index], X_train_params[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
    X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    # Save the model for each fold
    model = load_model(f'./models/model_2step_50-25resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

    train_err = model([X_train_params_k, X_train_pod_k]).numpy() - y_train_k
    test_err = model([X_val_params_k, X_val_pod_k]).numpy() - y_val_k
    mse_train = np.mean(train_err**2)
    mse_test = np.mean(test_err**2)
    rmse_train = np.mean(np.sqrt(train_err**2))
    rmse_test = np.mean(np.sqrt(test_err**2))

    # Increment the fold number
    fold_var += 1

print("Mean Squared error train: ", np.mean(mse_train))
print("Mean Squared error test: ", np.mean(mse_test))
print("Root Mean Squared error train: ", np.mean(rmse_train))
print("Root Mean Squared error test: ", np.mean(rmse_test))
# Out:
# Training fold 1...
# Training fold 2...
# Training fold 3...
# Training fold 4...
# Mean Squared error train:  1.776423147932263e-06
# Mean Squared error test:  6.039990468018876e-06
# Root Mean Squared error train:  0.0010306554318107199
# Root Mean Squared error test:  0.0017690447154885289

# %% [markdown]
# #### Additional input RESOLUTION 10-10

# %% [markdown]
# $N^o $ of samples = 2000

# %%
import numpy as np
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Add
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

Training = True

coeff = 1e-7
n_neurons = 256
n_splits = 4
n_sample = 2000

model_lf = load_model(f'./models/model_10resolution_64000samples_1.keras')

# Load the data
X_train_params = np.loadtxt('../../data/50-25-10/X_train_50resolution.csv', delimiter=',')[:n_sample,:]
X_train_pod = model_lf(X_train_params).numpy()[:n_sample,:]
y_train = np.loadtxt('../../data/50-25-10/y_train_50resolution.csv', delimiter=',')[:n_sample,:]

print(np.mean((X_train_pod - y_train)**2))

print(y_train)

X_test_params = np.loadtxt('../../data/50-25-10/X_test_50resolution.csv', delimiter=',')
X_test_pod = model_lf(X_test_params).numpy()
y_test = np.loadtxt('../../data/50-25-10/y_test_50resolution.csv', delimiter=',')

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch > 1000:
        return lr*(epoch)/(1+epoch)
    else:
        return max(lr * 0.999, 1e-7)
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 1

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(combined)
output = Dense(25, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

for train_index, val_index in kf.split(X_train_params):

    print(f"Training fold {fold_var}...")

    # Splitting the data into training and validation sets
    X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
    X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    # Compile the model
    initial_learning_rate = 0.001
    optimizer = Adam(learning_rate=initial_learning_rate)
    model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

    # Define the learning rate scheduler callback
    lr_scheduler = LearningRateScheduler(scheduler)

    # Train the model
    history = model.fit([X_train_params_k, X_train_pod_k], y_train_k,
                        epochs=1000,
                        batch_size=64,
                        validation_data=([X_val_params_k, X_val_pod_k], y_val_k),
                        validation_freq=10,
                        callbacks=[lr_scheduler])
    
    # Save the model for each fold
    model.save(f'./models/model_2step_50-10resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

    # Increment the fold number
    fold_var += 1
# Out:
# 0.0002916355300577195
# [[0.82843896 0.80762808 0.91036802 ... 0.19904088 0.23674059 0.32839533]
#  [0.8851561  0.89120142 0.84836334 ... 0.04889952 0.05757054 0.06519809]
#  [0.93718216 0.89983595 0.93218052 ... 0.06193638 0.03079713 0.01388359]
#  ...
#  [0.85917021 0.86226574 0.86832887 ... 0.0499593  0.04998812 0.06185904]
#  [0.92967734 0.91817288 0.92903502 ... 0.14890726 0.0953635  0.07168957]
#  [0.96514926 0.97976565 0.93927461 ... 0.15908284 0.10043792 0.19039906]]
# Training fold 1...
# Epoch 1/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1241 - mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 2/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - mean_squared_error: 0.0058 - learning_rate: 0.0010
# Epoch 3/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mean_squared_error: 0.0033 - learning_rate: 0.0010
# Epoch 4/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mean_squared_error: 0.0022 - learning_rate: 0.0010
# Epoch 5/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mean_squared_error: 0.0016 - learning_rate: 0.0010
# Epoch 6/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014 - mean_squared_error: 0.0012 - learning_rate: 0.0010
# Epoch 7/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_squared_error: 9.7212e-04 - learning_rate: 0.0010
# Epoch 8/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7382e-04 - mean_squared_error: 7.9736e-04 - learning_rate: 0.0010
# Epoch 9/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8358e-04 - mean_squared_error: 7.0697e-04 - learning_rate: 0.0010
# Epoch 10/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9649e-04 - mean_squared_error: 6.1984e-04 - val_loss: 9.4386e-04 - val_mean_squared_error: 7.6719e-04 - learning_rate: 0.0010
# Epoch 11/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2772e-04 - mean_squared_error: 5.5104e-04 - learning_rate: 9.9900e-04
# Epoch 12/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7354e-04 - mean_squared_error: 4.9687e-04 - learning_rate: 9.9800e-04
# Epoch 13/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3666e-04 - mean_squared_error: 4.5998e-04 - learning_rate: 9.9700e-04
# Epoch 14/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9059e-04 - mean_squared_error: 4.1394e-04 - learning_rate: 9.9601e-04
# Epoch 15/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6331e-04 - mean_squared_error: 3.8668e-04 - learning_rate: 9.9501e-04
# Epoch 16/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3932e-04 - mean_squared_error: 3.6271e-04 - learning_rate: 9.9402e-04
# Epoch 17/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1867e-04 - mean_squared_error: 3.4210e-04 - learning_rate: 9.9302e-04
# Epoch 18/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9194e-04 - mean_squared_error: 3.1540e-04 - learning_rate: 9.9203e-04
# Epoch 19/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7148e-04 - mean_squared_error: 2.9496e-04 - learning_rate: 9.9104e-04
# Epoch 20/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5871e-04 - mean_squared_error: 2.8223e-04 - val_loss: 6.9575e-04 - val_mean_squared_error: 5.1931e-04 - learning_rate: 9.9004e-04
# Epoch 21/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4390e-04 - mean_squared_error: 2.6746e-04 - learning_rate: 9.8905e-04
# Epoch 22/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2713e-04 - mean_squared_error: 2.5074e-04 - learning_rate: 9.8807e-04
# Epoch 23/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1697e-04 - mean_squared_error: 2.4061e-04 - learning_rate: 9.8708e-04
# Epoch 24/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9517e-04 - mean_squared_error: 2.1888e-04 - learning_rate: 9.8609e-04
# Epoch 25/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8579e-04 - mean_squared_error: 2.0952e-04 - learning_rate: 9.8510e-04
# Epoch 26/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7305e-04 - mean_squared_error: 1.9684e-04 - learning_rate: 9.8412e-04
# Epoch 27/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6601e-04 - mean_squared_error: 1.8985e-04 - learning_rate: 9.8314e-04
# Epoch 28/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5756e-04 - mean_squared_error: 1.8146e-04 - learning_rate: 9.8215e-04
# Epoch 29/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4570e-04 - mean_squared_error: 1.6967e-04 - learning_rate: 9.8117e-04
# Epoch 30/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3991e-04 - mean_squared_error: 1.6391e-04 - val_loss: 6.1595e-04 - val_mean_squared_error: 4.4002e-04 - learning_rate: 9.8019e-04
# Epoch 31/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3013e-04 - mean_squared_error: 1.5422e-04 - learning_rate: 9.7921e-04
# Epoch 32/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2567e-04 - mean_squared_error: 1.4983e-04 - learning_rate: 9.7823e-04
# Epoch 33/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2406e-04 - mean_squared_error: 1.4828e-04 - learning_rate: 9.7725e-04
# Epoch 34/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1168e-04 - mean_squared_error: 1.3599e-04 - learning_rate: 9.7627e-04
# Epoch 35/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0885e-04 - mean_squared_error: 1.3324e-04 - learning_rate: 9.7530e-04
# Epoch 36/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0080e-04 - mean_squared_error: 1.2527e-04 - learning_rate: 9.7432e-04
# Epoch 37/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0080e-04 - mean_squared_error: 1.2536e-04 - learning_rate: 9.7335e-04
# Epoch 38/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9565e-04 - mean_squared_error: 1.2031e-04 - learning_rate: 9.7237e-04
# Epoch 39/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8881e-04 - mean_squared_error: 1.1355e-04 - learning_rate: 9.7140e-04
# Epoch 40/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7942e-04 - mean_squared_error: 1.0427e-04 - val_loss: 5.6886e-04 - val_mean_squared_error: 3.9378e-04 - learning_rate: 9.7043e-04
# Epoch 41/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7622e-04 - mean_squared_error: 1.0117e-04 - learning_rate: 9.6946e-04
# Epoch 42/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7519e-04 - mean_squared_error: 1.0025e-04 - learning_rate: 9.6849e-04
# Epoch 43/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6831e-04 - mean_squared_error: 9.3479e-05 - learning_rate: 9.6752e-04
# Epoch 44/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6880e-04 - mean_squared_error: 9.4079e-05 - learning_rate: 9.6656e-04
# Epoch 45/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6650e-04 - mean_squared_error: 9.1892e-05 - learning_rate: 9.6559e-04
# Epoch 46/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5856e-04 - mean_squared_error: 8.4075e-05 - learning_rate: 9.6462e-04
# Epoch 47/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5952e-04 - mean_squared_error: 8.5166e-05 - learning_rate: 9.6366e-04
# Epoch 48/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5485e-04 - mean_squared_error: 8.0618e-05 - learning_rate: 9.6269e-04
# Epoch 49/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5140e-04 - mean_squared_error: 7.7288e-05 - learning_rate: 9.6173e-04
# Epoch 50/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5243e-04 - mean_squared_error: 7.8467e-05 - val_loss: 5.4710e-04 - val_mean_squared_error: 3.7323e-04 - learning_rate: 9.6077e-04
# Epoch 51/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4635e-04 - mean_squared_error: 7.2517e-05 - learning_rate: 9.5981e-04
# Epoch 52/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4344e-04 - mean_squared_error: 6.9748e-05 - learning_rate: 9.5885e-04
# Epoch 53/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3906e-04 - mean_squared_error: 6.5519e-05 - learning_rate: 9.5789e-04
# Epoch 54/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4161e-04 - mean_squared_error: 6.8203e-05 - learning_rate: 9.5693e-04
# Epoch 55/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3849e-04 - mean_squared_error: 6.5234e-05 - learning_rate: 9.5598e-04
# Epoch 56/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3693e-04 - mean_squared_error: 6.3832e-05 - learning_rate: 9.5502e-04
# Epoch 57/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3713e-04 - mean_squared_error: 6.4189e-05 - learning_rate: 9.5407e-04
# Epoch 58/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3497e-04 - mean_squared_error: 6.2197e-05 - learning_rate: 9.5311e-04
# Epoch 59/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2940e-04 - mean_squared_error: 5.6781e-05 - learning_rate: 9.5216e-04
# Epoch 60/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2803e-04 - mean_squared_error: 5.5579e-05 - val_loss: 5.2911e-04 - val_mean_squared_error: 3.5678e-04 - learning_rate: 9.5121e-04
# Epoch 61/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2740e-04 - mean_squared_error: 5.5116e-05 - learning_rate: 9.5025e-04
# Epoch 62/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2755e-04 - mean_squared_error: 5.5436e-05 - learning_rate: 9.4930e-04
# Epoch 63/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2717e-04 - mean_squared_error: 5.5236e-05 - learning_rate: 9.4835e-04
# Epoch 64/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2548e-04 - mean_squared_error: 5.3730e-05 - learning_rate: 9.4741e-04
# Epoch 65/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2317e-04 - mean_squared_error: 5.1599e-05 - learning_rate: 9.4646e-04
# Epoch 66/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1773e-04 - mean_squared_error: 4.6326e-05 - learning_rate: 9.4551e-04
# Epoch 67/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1704e-04 - mean_squared_error: 4.5827e-05 - learning_rate: 9.4457e-04
# Epoch 68/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1744e-04 - mean_squared_error: 4.6417e-05 - learning_rate: 9.4362e-04
# Epoch 69/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1650e-04 - mean_squared_error: 4.5666e-05 - learning_rate: 9.4268e-04
# Epoch 70/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1519e-04 - mean_squared_error: 4.4545e-05 - val_loss: 5.1662e-04 - val_mean_squared_error: 3.4612e-04 - learning_rate: 9.4174e-04
# Epoch 71/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1197e-04 - mean_squared_error: 4.1521e-05 - learning_rate: 9.4079e-04
# Epoch 72/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1275e-04 - mean_squared_error: 4.2491e-05 - learning_rate: 9.3985e-04
# Epoch 73/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0983e-04 - mean_squared_error: 3.9783e-05 - learning_rate: 9.3891e-04
# Epoch 74/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1110e-04 - mean_squared_error: 4.1262e-05 - learning_rate: 9.3798e-04
# Epoch 75/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0777e-04 - mean_squared_error: 3.8149e-05 - learning_rate: 9.3704e-04
# Epoch 76/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0776e-04 - mean_squared_error: 3.8343e-05 - learning_rate: 9.3610e-04
# Epoch 77/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0672e-04 - mean_squared_error: 3.7528e-05 - learning_rate: 9.3516e-04
# Epoch 78/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0477e-04 - mean_squared_error: 3.5795e-05 - learning_rate: 9.3423e-04
# Epoch 79/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0286e-04 - mean_squared_error: 3.4100e-05 - learning_rate: 9.3329e-04
# Epoch 80/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0510e-04 - mean_squared_error: 3.6563e-05 - val_loss: 4.9984e-04 - val_mean_squared_error: 3.3148e-04 - learning_rate: 9.3236e-04
# Epoch 81/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0467e-04 - mean_squared_error: 3.6357e-05 - learning_rate: 9.3143e-04
# Epoch 82/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0614e-04 - mean_squared_error: 3.8046e-05 - learning_rate: 9.3050e-04
# Epoch 83/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0198e-04 - mean_squared_error: 3.4108e-05 - learning_rate: 9.2957e-04
# Epoch 84/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0148e-04 - mean_squared_error: 3.3838e-05 - learning_rate: 9.2864e-04
# Epoch 85/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0110e-04 - mean_squared_error: 3.3690e-05 - learning_rate: 9.2771e-04
# Epoch 86/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9945e-04 - mean_squared_error: 3.2271e-05 - learning_rate: 9.2678e-04
# Epoch 87/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9929e-04 - mean_squared_error: 3.2347e-05 - learning_rate: 9.2585e-04
# Epoch 88/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9755e-04 - mean_squared_error: 3.0846e-05 - learning_rate: 9.2493e-04
# Epoch 89/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9612e-04 - mean_squared_error: 2.9651e-05 - learning_rate: 9.2400e-04
# Epoch 90/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9793e-04 - mean_squared_error: 3.1707e-05 - val_loss: 4.9406e-04 - val_mean_squared_error: 3.2803e-04 - learning_rate: 9.2308e-04
# Epoch 91/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9596e-04 - mean_squared_error: 2.9984e-05 - learning_rate: 9.2216e-04
# Epoch 92/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9489e-04 - mean_squared_error: 2.9162e-05 - learning_rate: 9.2123e-04
# Epoch 93/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9563e-04 - mean_squared_error: 3.0147e-05 - learning_rate: 9.2031e-04
# Epoch 94/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9577e-04 - mean_squared_error: 3.0547e-05 - learning_rate: 9.1939e-04
# Epoch 95/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9689e-04 - mean_squared_error: 3.1922e-05 - learning_rate: 9.1847e-04
# Epoch 96/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9700e-04 - mean_squared_error: 3.2288e-05 - learning_rate: 9.1755e-04
# Epoch 97/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9740e-04 - mean_squared_error: 3.2940e-05 - learning_rate: 9.1664e-04
# Epoch 98/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9588e-04 - mean_squared_error: 3.1659e-05 - learning_rate: 9.1572e-04
# Epoch 99/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9290e-04 - mean_squared_error: 2.8949e-05 - learning_rate: 9.1480e-04
# Epoch 100/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9093e-04 - mean_squared_error: 2.7220e-05 - val_loss: 4.8210e-04 - val_mean_squared_error: 3.1857e-04 - learning_rate: 9.1389e-04
# Epoch 101/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9044e-04 - mean_squared_error: 2.6984e-05 - learning_rate: 9.1298e-04
# Epoch 102/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9032e-04 - mean_squared_error: 2.7127e-05 - learning_rate: 9.1206e-04
# Epoch 103/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8865e-04 - mean_squared_error: 2.5721e-05 - learning_rate: 9.1115e-04
# Epoch 104/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8935e-04 - mean_squared_error: 2.6683e-05 - learning_rate: 9.1024e-04
# Epoch 105/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9008e-04 - mean_squared_error: 2.7689e-05 - learning_rate: 9.0933e-04
# Epoch 106/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8738e-04 - mean_squared_error: 2.5268e-05 - learning_rate: 9.0842e-04
# Epoch 107/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8996e-04 - mean_squared_error: 2.8112e-05 - learning_rate: 9.0751e-04
# Epoch 108/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8679e-04 - mean_squared_error: 2.5214e-05 - learning_rate: 9.0660e-04
# Epoch 109/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8294e-04 - mean_squared_error: 2.1641e-05 - learning_rate: 9.0570e-04
# Epoch 110/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8334e-04 - mean_squared_error: 2.2331e-05 - val_loss: 4.7256e-04 - val_mean_squared_error: 3.1175e-04 - learning_rate: 9.0479e-04
# Epoch 111/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8282e-04 - mean_squared_error: 2.2074e-05 - learning_rate: 9.0389e-04
# Epoch 112/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8334e-04 - mean_squared_error: 2.2887e-05 - learning_rate: 9.0298e-04
# Epoch 113/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8286e-04 - mean_squared_error: 2.2694e-05 - learning_rate: 9.0208e-04
# Epoch 114/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8228e-04 - mean_squared_error: 2.2413e-05 - learning_rate: 9.0118e-04
# Epoch 115/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8176e-04 - mean_squared_error: 2.2178e-05 - learning_rate: 9.0028e-04
# Epoch 116/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8023e-04 - mean_squared_error: 2.0957e-05 - learning_rate: 8.9938e-04
# Epoch 117/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8177e-04 - mean_squared_error: 2.2794e-05 - learning_rate: 8.9848e-04
# Epoch 118/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8170e-04 - mean_squared_error: 2.3023e-05 - learning_rate: 8.9758e-04
# Epoch 119/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8015e-04 - mean_squared_error: 2.1765e-05 - learning_rate: 8.9668e-04
# Epoch 120/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8189e-04 - mean_squared_error: 2.3811e-05 - val_loss: 4.7188e-04 - val_mean_squared_error: 3.1401e-04 - learning_rate: 8.9578e-04
# Epoch 121/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8840e-04 - mean_squared_error: 3.0616e-05 - learning_rate: 8.9489e-04
# Epoch 122/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9066e-04 - mean_squared_error: 3.3165e-05 - learning_rate: 8.9399e-04
# Epoch 123/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8416e-04 - mean_squared_error: 2.6945e-05 - learning_rate: 8.9310e-04
# Epoch 124/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7982e-04 - mean_squared_error: 2.2903e-05 - learning_rate: 8.9221e-04
# Epoch 125/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9541e-04 - mean_squared_error: 3.8769e-05 - learning_rate: 8.9131e-04
# Epoch 126/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8809e-04 - mean_squared_error: 3.1741e-05 - learning_rate: 8.9042e-04
# Epoch 127/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8492e-04 - mean_squared_error: 2.8859e-05 - learning_rate: 8.8953e-04
# Epoch 128/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8534e-04 - mean_squared_error: 2.9581e-05 - learning_rate: 8.8864e-04
# Epoch 129/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8097e-04 - mean_squared_error: 2.5510e-05 - learning_rate: 8.8775e-04
# Epoch 130/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8879e-04 - mean_squared_error: 3.3637e-05 - val_loss: 4.5603e-04 - val_mean_squared_error: 3.0109e-04 - learning_rate: 8.8687e-04
# Epoch 131/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7908e-04 - mean_squared_error: 2.4218e-05 - learning_rate: 8.8598e-04
# Epoch 132/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7880e-04 - mean_squared_error: 2.4247e-05 - learning_rate: 8.8509e-04
# Epoch 133/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7370e-04 - mean_squared_error: 1.9452e-05 - learning_rate: 8.8421e-04
# Epoch 134/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7248e-04 - mean_squared_error: 1.8528e-05 - learning_rate: 8.8333e-04
# Epoch 135/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7447e-04 - mean_squared_error: 2.0843e-05 - learning_rate: 8.8244e-04
# Epoch 136/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7092e-04 - mean_squared_error: 1.7615e-05 - learning_rate: 8.8156e-04
# Epoch 137/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7009e-04 - mean_squared_error: 1.7111e-05 - learning_rate: 8.8068e-04
# Epoch 138/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7073e-04 - mean_squared_error: 1.8066e-05 - learning_rate: 8.7980e-04
# Epoch 139/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7103e-04 - mean_squared_error: 1.8690e-05 - learning_rate: 8.7892e-04
# Epoch 140/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7061e-04 - mean_squared_error: 1.8591e-05 - val_loss: 4.4274e-04 - val_mean_squared_error: 2.9097e-04 - learning_rate: 8.7804e-04
# Epoch 141/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7351e-04 - mean_squared_error: 2.1827e-05 - learning_rate: 8.7716e-04
# Epoch 142/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7030e-04 - mean_squared_error: 1.8951e-05 - learning_rate: 8.7628e-04
# Epoch 143/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7284e-04 - mean_squared_error: 2.1809e-05 - learning_rate: 8.7541e-04
# Epoch 144/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7047e-04 - mean_squared_error: 1.9775e-05 - learning_rate: 8.7453e-04
# Epoch 145/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7353e-04 - mean_squared_error: 2.3150e-05 - learning_rate: 8.7366e-04
# Epoch 146/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7293e-04 - mean_squared_error: 2.2874e-05 - learning_rate: 8.7278e-04
# Epoch 147/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7276e-04 - mean_squared_error: 2.3028e-05 - learning_rate: 8.7191e-04
# Epoch 148/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7585e-04 - mean_squared_error: 2.6453e-05 - learning_rate: 8.7104e-04
# Epoch 149/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7315e-04 - mean_squared_error: 2.4078e-05 - learning_rate: 8.7017e-04
# Epoch 150/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7282e-04 - mean_squared_error: 2.4072e-05 - val_loss: 4.3708e-04 - val_mean_squared_error: 2.8858e-04 - learning_rate: 8.6930e-04
# Epoch 151/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7722e-04 - mean_squared_error: 2.8803e-05 - learning_rate: 8.6843e-04
# Epoch 152/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7048e-04 - mean_squared_error: 2.2411e-05 - learning_rate: 8.6756e-04
# Epoch 153/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6634e-04 - mean_squared_error: 1.8604e-05 - learning_rate: 8.6669e-04
# Epoch 154/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6371e-04 - mean_squared_error: 1.6307e-05 - learning_rate: 8.6583e-04
# Epoch 155/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6314e-04 - mean_squared_error: 1.6066e-05 - learning_rate: 8.6496e-04
# Epoch 156/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6499e-04 - mean_squared_error: 1.8264e-05 - learning_rate: 8.6409e-04
# Epoch 157/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6684e-04 - mean_squared_error: 2.0465e-05 - learning_rate: 8.6323e-04
# Epoch 158/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6891e-04 - mean_squared_error: 2.2870e-05 - learning_rate: 8.6237e-04
# Epoch 159/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7337e-04 - mean_squared_error: 2.7669e-05 - learning_rate: 8.6151e-04
# Epoch 160/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7004e-04 - mean_squared_error: 2.4662e-05 - val_loss: 4.2933e-04 - val_mean_squared_error: 2.8419e-04 - learning_rate: 8.6064e-04
# Epoch 161/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7775e-04 - mean_squared_error: 3.2699e-05 - learning_rate: 8.5978e-04
# Epoch 162/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6982e-04 - mean_squared_error: 2.5092e-05 - learning_rate: 8.5892e-04
# Epoch 163/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6499e-04 - mean_squared_error: 2.0606e-05 - learning_rate: 8.5806e-04
# Epoch 164/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6485e-04 - mean_squared_error: 2.0788e-05 - learning_rate: 8.5721e-04
# Epoch 165/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6934e-04 - mean_squared_error: 2.5634e-05 - learning_rate: 8.5635e-04
# Epoch 166/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6371e-04 - mean_squared_error: 2.0334e-05 - learning_rate: 8.5549e-04
# Epoch 167/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7592e-04 - mean_squared_error: 3.2878e-05 - learning_rate: 8.5464e-04
# Epoch 168/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7822e-04 - mean_squared_error: 3.5525e-05 - learning_rate: 8.5378e-04
# Epoch 169/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6895e-04 - mean_squared_error: 2.6570e-05 - learning_rate: 8.5293e-04
# Epoch 170/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6761e-04 - mean_squared_error: 2.5555e-05 - val_loss: 4.2308e-04 - val_mean_squared_error: 2.8127e-04 - learning_rate: 8.5208e-04
# Epoch 171/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6510e-04 - mean_squared_error: 2.3378e-05 - learning_rate: 8.5122e-04
# Epoch 172/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6113e-04 - mean_squared_error: 1.9745e-05 - learning_rate: 8.5037e-04
# Epoch 173/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5792e-04 - mean_squared_error: 1.6900e-05 - learning_rate: 8.4952e-04
# Epoch 174/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5725e-04 - mean_squared_error: 1.6559e-05 - learning_rate: 8.4867e-04
# Epoch 175/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5816e-04 - mean_squared_error: 1.7811e-05 - learning_rate: 8.4782e-04
# Epoch 176/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5719e-04 - mean_squared_error: 1.7203e-05 - learning_rate: 8.4698e-04
# Epoch 177/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6265e-04 - mean_squared_error: 2.3027e-05 - learning_rate: 8.4613e-04
# Epoch 178/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5631e-04 - mean_squared_error: 1.7039e-05 - learning_rate: 8.4528e-04
# Epoch 179/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5566e-04 - mean_squared_error: 1.6738e-05 - learning_rate: 8.4444e-04
# Epoch 180/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5477e-04 - mean_squared_error: 1.6193e-05 - val_loss: 4.0455e-04 - val_mean_squared_error: 2.6625e-04 - learning_rate: 8.4359e-04
# Epoch 181/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5363e-04 - mean_squared_error: 1.5426e-05 - learning_rate: 8.4275e-04
# Epoch 182/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6210e-04 - mean_squared_error: 2.4258e-05 - learning_rate: 8.4191e-04
# Epoch 183/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6014e-04 - mean_squared_error: 2.2653e-05 - learning_rate: 8.4106e-04
# Epoch 184/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5623e-04 - mean_squared_error: 1.9099e-05 - learning_rate: 8.4022e-04
# Epoch 185/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5272e-04 - mean_squared_error: 1.5938e-05 - learning_rate: 8.3938e-04
# Epoch 186/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5264e-04 - mean_squared_error: 1.6211e-05 - learning_rate: 8.3854e-04
# Epoch 187/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6027e-04 - mean_squared_error: 2.4201e-05 - learning_rate: 8.3771e-04
# Epoch 188/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5888e-04 - mean_squared_error: 2.3173e-05 - learning_rate: 8.3687e-04
# Epoch 189/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6267e-04 - mean_squared_error: 2.7329e-05 - learning_rate: 8.3603e-04
# Epoch 190/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6090e-04 - mean_squared_error: 2.5895e-05 - val_loss: 3.9961e-04 - val_mean_squared_error: 2.6486e-04 - learning_rate: 8.3520e-04
# Epoch 191/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5949e-04 - mean_squared_error: 2.4824e-05 - learning_rate: 8.3436e-04
# Epoch 192/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5489e-04 - mean_squared_error: 2.0557e-05 - learning_rate: 8.3353e-04
# Epoch 193/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5125e-04 - mean_squared_error: 1.7268e-05 - learning_rate: 8.3269e-04
# Epoch 194/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4984e-04 - mean_squared_error: 1.6211e-05 - learning_rate: 8.3186e-04
# Epoch 195/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5230e-04 - mean_squared_error: 1.9039e-05 - learning_rate: 8.3103e-04
# Epoch 196/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5314e-04 - mean_squared_error: 2.0265e-05 - learning_rate: 8.3020e-04
# Epoch 197/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4905e-04 - mean_squared_error: 1.6522e-05 - learning_rate: 8.2937e-04
# Epoch 198/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5584e-04 - mean_squared_error: 2.3682e-05 - learning_rate: 8.2854e-04
# Epoch 199/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6723e-04 - mean_squared_error: 3.5437e-05 - learning_rate: 8.2771e-04
# Epoch 200/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5422e-04 - mean_squared_error: 2.2755e-05 - val_loss: 4.0441e-04 - val_mean_squared_error: 2.7319e-04 - learning_rate: 8.2688e-04
# Epoch 201/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5997e-04 - mean_squared_error: 2.8836e-05 - learning_rate: 8.2605e-04
# Epoch 202/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5714e-04 - mean_squared_error: 2.6360e-05 - learning_rate: 8.2523e-04
# Epoch 203/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4590e-04 - mean_squared_error: 1.5464e-05 - learning_rate: 8.2440e-04
# Epoch 204/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4477e-04 - mean_squared_error: 1.4696e-05 - learning_rate: 8.2358e-04
# Epoch 205/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4674e-04 - mean_squared_error: 1.7037e-05 - learning_rate: 8.2275e-04
# Epoch 206/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4589e-04 - mean_squared_error: 1.6532e-05 - learning_rate: 8.2193e-04
# Epoch 207/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4455e-04 - mean_squared_error: 1.5562e-05 - learning_rate: 8.2111e-04
# Epoch 208/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4595e-04 - mean_squared_error: 1.7335e-05 - learning_rate: 8.2029e-04
# Epoch 209/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4507e-04 - mean_squared_error: 1.6798e-05 - learning_rate: 8.1947e-04
# Epoch 210/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5012e-04 - mean_squared_error: 2.2210e-05 - val_loss: 3.8909e-04 - val_mean_squared_error: 2.6148e-04 - learning_rate: 8.1865e-04
# Epoch 211/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5716e-04 - mean_squared_error: 2.9627e-05 - learning_rate: 8.1783e-04
# Epoch 212/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9148e-04 - mean_squared_error: 6.4270e-05 - learning_rate: 8.1701e-04
# Epoch 213/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6028e-04 - mean_squared_error: 3.3412e-05 - learning_rate: 8.1620e-04
# Epoch 214/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6150e-04 - mean_squared_error: 3.4959e-05 - learning_rate: 8.1538e-04
# Epoch 215/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4726e-04 - mean_squared_error: 2.1048e-05 - learning_rate: 8.1456e-04
# Epoch 216/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4681e-04 - mean_squared_error: 2.0939e-05 - learning_rate: 8.1375e-04
# Epoch 217/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4518e-04 - mean_squared_error: 1.9669e-05 - learning_rate: 8.1294e-04
# Epoch 218/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4216e-04 - mean_squared_error: 1.6989e-05 - learning_rate: 8.1212e-04
# Epoch 219/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4054e-04 - mean_squared_error: 1.5711e-05 - learning_rate: 8.1131e-04
# Epoch 220/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3964e-04 - mean_squared_error: 1.5189e-05 - val_loss: 3.6972e-04 - val_mean_squared_error: 2.4553e-04 - learning_rate: 8.1050e-04
# Epoch 221/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3818e-04 - mean_squared_error: 1.4080e-05 - learning_rate: 8.0969e-04
# Epoch 222/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3912e-04 - mean_squared_error: 1.5403e-05 - learning_rate: 8.0888e-04
# Epoch 223/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3685e-04 - mean_squared_error: 1.3493e-05 - learning_rate: 8.0807e-04
# Epoch 224/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3746e-04 - mean_squared_error: 1.4486e-05 - learning_rate: 8.0726e-04
# Epoch 225/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3700e-04 - mean_squared_error: 1.4400e-05 - learning_rate: 8.0645e-04
# Epoch 226/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4133e-04 - mean_squared_error: 1.9097e-05 - learning_rate: 8.0565e-04
# Epoch 227/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3759e-04 - mean_squared_error: 1.5738e-05 - learning_rate: 8.0484e-04
# Epoch 228/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4917e-04 - mean_squared_error: 2.7667e-05 - learning_rate: 8.0404e-04
# Epoch 229/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4168e-04 - mean_squared_error: 2.0535e-05 - learning_rate: 8.0323e-04
# Epoch 230/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4414e-04 - mean_squared_error: 2.3348e-05 - val_loss: 3.7528e-04 - val_mean_squared_error: 2.5476e-04 - learning_rate: 8.0243e-04
# Epoch 231/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4044e-04 - mean_squared_error: 2.0002e-05 - learning_rate: 8.0163e-04
# Epoch 232/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3976e-04 - mean_squared_error: 1.9672e-05 - learning_rate: 8.0083e-04
# Epoch 233/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3725e-04 - mean_squared_error: 1.7537e-05 - learning_rate: 8.0003e-04
# Epoch 234/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3411e-04 - mean_squared_error: 1.4758e-05 - learning_rate: 7.9923e-04
# Epoch 235/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3441e-04 - mean_squared_error: 1.5416e-05 - learning_rate: 7.9843e-04
# Epoch 236/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3403e-04 - mean_squared_error: 1.5412e-05 - learning_rate: 7.9763e-04
# Epoch 237/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3662e-04 - mean_squared_error: 1.8352e-05 - learning_rate: 7.9683e-04
# Epoch 238/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3711e-04 - mean_squared_error: 1.9216e-05 - learning_rate: 7.9603e-04
# Epoch 239/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3782e-04 - mean_squared_error: 2.0269e-05 - learning_rate: 7.9524e-04
# Epoch 240/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3398e-04 - mean_squared_error: 1.6789e-05 - val_loss: 3.6009e-04 - val_mean_squared_error: 2.4316e-04 - learning_rate: 7.9444e-04
# Epoch 241/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3679e-04 - mean_squared_error: 1.9942e-05 - learning_rate: 7.9365e-04
# Epoch 242/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3682e-04 - mean_squared_error: 2.0327e-05 - learning_rate: 7.9285e-04
# Epoch 243/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3736e-04 - mean_squared_error: 2.1216e-05 - learning_rate: 7.9206e-04
# Epoch 244/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3451e-04 - mean_squared_error: 1.8720e-05 - learning_rate: 7.9127e-04
# Epoch 245/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3109e-04 - mean_squared_error: 1.5646e-05 - learning_rate: 7.9048e-04
# Epoch 246/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2988e-04 - mean_squared_error: 1.4792e-05 - learning_rate: 7.8969e-04
# Epoch 247/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3263e-04 - mean_squared_error: 1.7894e-05 - learning_rate: 7.8890e-04
# Epoch 248/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4874e-04 - mean_squared_error: 3.4384e-05 - learning_rate: 7.8811e-04
# Epoch 249/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3677e-04 - mean_squared_error: 2.2729e-05 - learning_rate: 7.8732e-04
# Epoch 250/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3229e-04 - mean_squared_error: 1.8575e-05 - val_loss: 3.5987e-04 - val_mean_squared_error: 2.4642e-04 - learning_rate: 7.8653e-04
# Epoch 251/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3422e-04 - mean_squared_error: 2.0864e-05 - learning_rate: 7.8575e-04
# Epoch 252/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3057e-04 - mean_squared_error: 1.7562e-05 - learning_rate: 7.8496e-04
# Epoch 253/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3071e-04 - mean_squared_error: 1.8057e-05 - learning_rate: 7.8418e-04
# Epoch 254/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2855e-04 - mean_squared_error: 1.6240e-05 - learning_rate: 7.8339e-04
# Epoch 255/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2705e-04 - mean_squared_error: 1.5070e-05 - learning_rate: 7.8261e-04
# Epoch 256/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2659e-04 - mean_squared_error: 1.4987e-05 - learning_rate: 7.8183e-04
# Epoch 257/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2609e-04 - mean_squared_error: 1.4825e-05 - learning_rate: 7.8104e-04
# Epoch 258/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2443e-04 - mean_squared_error: 1.3526e-05 - learning_rate: 7.8026e-04
# Epoch 259/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2668e-04 - mean_squared_error: 1.6131e-05 - learning_rate: 7.7948e-04
# Epoch 260/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2326e-04 - mean_squared_error: 1.3060e-05 - val_loss: 3.3845e-04 - val_mean_squared_error: 2.2851e-04 - learning_rate: 7.7870e-04
# Epoch 261/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2319e-04 - mean_squared_error: 1.3331e-05 - learning_rate: 7.7792e-04
# Epoch 262/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2165e-04 - mean_squared_error: 1.2151e-05 - learning_rate: 7.7715e-04
# Epoch 263/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2354e-04 - mean_squared_error: 1.4411e-05 - learning_rate: 7.7637e-04
# Epoch 264/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2576e-04 - mean_squared_error: 1.6994e-05 - learning_rate: 7.7559e-04
# Epoch 265/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2593e-04 - mean_squared_error: 1.7499e-05 - learning_rate: 7.7482e-04
# Epoch 266/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4987e-04 - mean_squared_error: 4.1785e-05 - learning_rate: 7.7404e-04
# Epoch 267/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4021e-04 - mean_squared_error: 3.2454e-05 - learning_rate: 7.7327e-04
# Epoch 268/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3277e-04 - mean_squared_error: 2.5315e-05 - learning_rate: 7.7250e-04
# Epoch 269/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3254e-04 - mean_squared_error: 2.5425e-05 - learning_rate: 7.7172e-04
# Epoch 270/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2882e-04 - mean_squared_error: 2.2013e-05 - val_loss: 3.4583e-04 - val_mean_squared_error: 2.3928e-04 - learning_rate: 7.7095e-04
# Epoch 271/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3421e-04 - mean_squared_error: 2.7734e-05 - learning_rate: 7.7018e-04
# Epoch 272/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2310e-04 - mean_squared_error: 1.6941e-05 - learning_rate: 7.6941e-04
# Epoch 273/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2132e-04 - mean_squared_error: 1.5487e-05 - learning_rate: 7.6864e-04
# Epoch 274/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2090e-04 - mean_squared_error: 1.5419e-05 - learning_rate: 7.6787e-04
# Epoch 275/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2094e-04 - mean_squared_error: 1.5785e-05 - learning_rate: 7.6710e-04
# Epoch 276/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1881e-04 - mean_squared_error: 1.3996e-05 - learning_rate: 7.6634e-04
# Epoch 277/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1573e-04 - mean_squared_error: 1.1261e-05 - learning_rate: 7.6557e-04
# Epoch 278/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1577e-04 - mean_squared_error: 1.1632e-05 - learning_rate: 7.6481e-04
# Epoch 279/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1773e-04 - mean_squared_error: 1.3945e-05 - learning_rate: 7.6404e-04
# Epoch 280/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2331e-04 - mean_squared_error: 1.9871e-05 - val_loss: 3.2484e-04 - val_mean_squared_error: 2.2164e-04 - learning_rate: 7.6328e-04
# Epoch 281/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2236e-04 - mean_squared_error: 1.9254e-05 - learning_rate: 7.6251e-04
# Epoch 282/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1676e-04 - mean_squared_error: 1.3975e-05 - learning_rate: 7.6175e-04
# Epoch 283/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1729e-04 - mean_squared_error: 1.4835e-05 - learning_rate: 7.6099e-04
# Epoch 284/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1767e-04 - mean_squared_error: 1.5528e-05 - learning_rate: 7.6023e-04
# Epoch 285/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1545e-04 - mean_squared_error: 1.3655e-05 - learning_rate: 7.5947e-04
# Epoch 286/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1903e-04 - mean_squared_error: 1.7557e-05 - learning_rate: 7.5871e-04
# Epoch 287/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1747e-04 - mean_squared_error: 1.6322e-05 - learning_rate: 7.5795e-04
# Epoch 288/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2325e-04 - mean_squared_error: 2.2448e-05 - learning_rate: 7.5719e-04
# Epoch 289/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2157e-04 - mean_squared_error: 2.1093e-05 - learning_rate: 7.5643e-04
# Epoch 290/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1861e-04 - mean_squared_error: 1.8442e-05 - val_loss: 3.2554e-04 - val_mean_squared_error: 2.2561e-04 - learning_rate: 7.5568e-04
# Epoch 291/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2518e-04 - mean_squared_error: 2.5327e-05 - learning_rate: 7.5492e-04
# Epoch 292/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2978e-04 - mean_squared_error: 3.0225e-05 - learning_rate: 7.5417e-04
# Epoch 293/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2801e-04 - mean_squared_error: 2.8752e-05 - learning_rate: 7.5341e-04
# Epoch 294/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2292e-04 - mean_squared_error: 2.3965e-05 - learning_rate: 7.5266e-04
# Epoch 295/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1777e-04 - mean_squared_error: 1.9096e-05 - learning_rate: 7.5191e-04
# Epoch 296/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1944e-04 - mean_squared_error: 2.1092e-05 - learning_rate: 7.5116e-04
# Epoch 297/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2219e-04 - mean_squared_error: 2.4157e-05 - learning_rate: 7.5040e-04
# Epoch 298/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1548e-04 - mean_squared_error: 1.7736e-05 - learning_rate: 7.4965e-04
# Epoch 299/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1365e-04 - mean_squared_error: 1.6196e-05 - learning_rate: 7.4890e-04
# Epoch 300/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1192e-04 - mean_squared_error: 1.4779e-05 - val_loss: 3.0726e-04 - val_mean_squared_error: 2.1036e-04 - learning_rate: 7.4816e-04
# Epoch 301/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1054e-04 - mean_squared_error: 1.3711e-05 - learning_rate: 7.4741e-04
# Epoch 302/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1541e-04 - mean_squared_error: 1.8897e-05 - learning_rate: 7.4666e-04
# Epoch 303/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2290e-04 - mean_squared_error: 2.6683e-05 - learning_rate: 7.4591e-04
# Epoch 304/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1634e-04 - mean_squared_error: 2.0387e-05 - learning_rate: 7.4517e-04
# Epoch 305/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0975e-04 - mean_squared_error: 1.4096e-05 - learning_rate: 7.4442e-04
# Epoch 306/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1120e-04 - mean_squared_error: 1.5841e-05 - learning_rate: 7.4368e-04
# Epoch 307/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0796e-04 - mean_squared_error: 1.2930e-05 - learning_rate: 7.4293e-04
# Epoch 308/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0662e-04 - mean_squared_error: 1.1898e-05 - learning_rate: 7.4219e-04
# Epoch 309/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0698e-04 - mean_squared_error: 1.2582e-05 - learning_rate: 7.4145e-04
# Epoch 310/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0673e-04 - mean_squared_error: 1.2640e-05 - val_loss: 3.0595e-04 - val_mean_squared_error: 2.1210e-04 - learning_rate: 7.4071e-04
# Epoch 311/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1101e-04 - mean_squared_error: 1.7236e-05 - learning_rate: 7.3997e-04
# Epoch 312/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0977e-04 - mean_squared_error: 1.6316e-05 - learning_rate: 7.3923e-04
# Epoch 313/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0542e-04 - mean_squared_error: 1.2251e-05 - learning_rate: 7.3849e-04
# Epoch 314/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0394e-04 - mean_squared_error: 1.1070e-05 - learning_rate: 7.3775e-04
# Epoch 315/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0416e-04 - mean_squared_error: 1.1605e-05 - learning_rate: 7.3701e-04
# Epoch 316/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0242e-04 - mean_squared_error: 1.0190e-05 - learning_rate: 7.3627e-04
# Epoch 317/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0246e-04 - mean_squared_error: 1.0528e-05 - learning_rate: 7.3554e-04
# Epoch 318/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0402e-04 - mean_squared_error: 1.2403e-05 - learning_rate: 7.3480e-04
# Epoch 319/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0365e-04 - mean_squared_error: 1.2340e-05 - learning_rate: 7.3407e-04
# Epoch 320/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1279e-04 - mean_squared_error: 2.1787e-05 - val_loss: 3.0396e-04 - val_mean_squared_error: 2.1315e-04 - learning_rate: 7.3333e-04
# Epoch 321/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0812e-04 - mean_squared_error: 1.7390e-05 - learning_rate: 7.3260e-04
# Epoch 322/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0976e-04 - mean_squared_error: 1.9335e-05 - learning_rate: 7.3187e-04
# Epoch 323/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0985e-04 - mean_squared_error: 1.9711e-05 - learning_rate: 7.3114e-04
# Epoch 324/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0650e-04 - mean_squared_error: 1.6629e-05 - learning_rate: 7.3040e-04
# Epoch 325/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0466e-04 - mean_squared_error: 1.5073e-05 - learning_rate: 7.2967e-04
# Epoch 326/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0255e-04 - mean_squared_error: 1.3227e-05 - learning_rate: 7.2894e-04
# Epoch 327/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0218e-04 - mean_squared_error: 1.3147e-05 - learning_rate: 7.2822e-04
# Epoch 328/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0121e-04 - mean_squared_error: 1.2469e-05 - learning_rate: 7.2749e-04
# Epoch 329/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0272e-04 - mean_squared_error: 1.4272e-05 - learning_rate: 7.2676e-04
# Epoch 330/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0193e-04 - mean_squared_error: 1.3780e-05 - val_loss: 2.9039e-04 - val_mean_squared_error: 2.0247e-04 - learning_rate: 7.2603e-04
# Epoch 331/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0534e-04 - mean_squared_error: 1.7480e-05 - learning_rate: 7.2531e-04
# Epoch 332/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0262e-04 - mean_squared_error: 1.5044e-05 - learning_rate: 7.2458e-04
# Epoch 333/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0319e-04 - mean_squared_error: 1.5886e-05 - learning_rate: 7.2386e-04
# Epoch 334/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0604e-04 - mean_squared_error: 1.9012e-05 - learning_rate: 7.2313e-04
# Epoch 335/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0297e-04 - mean_squared_error: 1.6200e-05 - learning_rate: 7.2241e-04
# Epoch 336/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0954e-04 - mean_squared_error: 2.3033e-05 - learning_rate: 7.2169e-04
# Epoch 337/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0573e-04 - mean_squared_error: 1.9484e-05 - learning_rate: 7.2097e-04
# Epoch 338/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0970e-04 - mean_squared_error: 2.3703e-05 - learning_rate: 7.2024e-04
# Epoch 339/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0903e-04 - mean_squared_error: 2.3272e-05 - learning_rate: 7.1952e-04
# Epoch 340/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0384e-04 - mean_squared_error: 1.8337e-05 - val_loss: 2.8778e-04 - val_mean_squared_error: 2.0246e-04 - learning_rate: 7.1881e-04
# Epoch 341/1000
# ...
# Epoch 316/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9887e-05 - mean_squared_error: 1.0994e-05 - learning_rate: 7.3627e-04
# Epoch 317/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8765e-05 - mean_squared_error: 9.9003e-06 - learning_rate: 7.3554e-04
# Epoch 318/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8243e-05 - mean_squared_error: 9.4000e-06 - learning_rate: 7.3480e-04
# Epoch 319/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7322e-05 - mean_squared_error: 8.5081e-06 - learning_rate: 7.3407e-04
# Epoch 320/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5614e-05 - mean_squared_error: 6.8300e-06 - val_loss: 1.0988e-04 - val_mean_squared_error: 7.1127e-05 - learning_rate: 7.3333e-04
# Epoch 321/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6386e-05 - mean_squared_error: 7.6453e-06 - learning_rate: 7.3260e-04
# Epoch 322/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5328e-05 - mean_squared_error: 6.6289e-06 - learning_rate: 7.3187e-04
# Epoch 323/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4976e-05 - mean_squared_error: 6.3247e-06 - learning_rate: 7.3114e-04
# Epoch 324/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4360e-05 - mean_squared_error: 5.7543e-06 - learning_rate: 7.3040e-04
# Epoch 325/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5757e-05 - mean_squared_error: 7.1957e-06 - learning_rate: 7.2967e-04
# Epoch 326/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7563e-05 - mean_squared_error: 9.0397e-06 - learning_rate: 7.2894e-04
# Epoch 327/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1959e-05 - mean_squared_error: 1.3469e-05 - learning_rate: 7.2822e-04
# Epoch 328/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7908e-05 - mean_squared_error: 1.9414e-05 - learning_rate: 7.2749e-04
# Epoch 329/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3023e-05 - mean_squared_error: 1.4513e-05 - learning_rate: 7.2676e-04
# Epoch 330/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1336e-05 - mean_squared_error: 1.2806e-05 - val_loss: 1.1178e-04 - val_mean_squared_error: 7.3245e-05 - learning_rate: 7.2603e-04
# Epoch 331/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9797e-05 - mean_squared_error: 1.1264e-05 - learning_rate: 7.2531e-04
# Epoch 332/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3089e-05 - mean_squared_error: 1.4562e-05 - learning_rate: 7.2458e-04
# Epoch 333/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0564e-05 - mean_squared_error: 1.2041e-05 - learning_rate: 7.2386e-04
# Epoch 334/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9578e-05 - mean_squared_error: 1.1051e-05 - learning_rate: 7.2313e-04
# Epoch 335/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8679e-05 - mean_squared_error: 1.0155e-05 - learning_rate: 7.2241e-04
# Epoch 336/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9385e-05 - mean_squared_error: 1.0887e-05 - learning_rate: 7.2169e-04
# Epoch 337/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8287e-05 - mean_squared_error: 9.8204e-06 - learning_rate: 7.2097e-04
# Epoch 338/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7908e-05 - mean_squared_error: 9.4596e-06 - learning_rate: 7.2024e-04
# Epoch 339/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8488e-05 - mean_squared_error: 1.0055e-05 - learning_rate: 7.1952e-04
# Epoch 340/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8165e-05 - mean_squared_error: 9.7492e-06 - val_loss: 1.1270e-04 - val_mean_squared_error: 7.4308e-05 - learning_rate: 7.1881e-04
# Epoch 341/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7152e-05 - mean_squared_error: 8.7658e-06 - learning_rate: 7.1809e-04
# Epoch 342/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7356e-05 - mean_squared_error: 9.0046e-06 - learning_rate: 7.1737e-04
# Epoch 343/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1023e-05 - mean_squared_error: 1.2696e-05 - learning_rate: 7.1665e-04
# Epoch 344/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7196e-05 - mean_squared_error: 8.8755e-06 - learning_rate: 7.1593e-04
# Epoch 345/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6564e-05 - mean_squared_error: 8.2776e-06 - learning_rate: 7.1522e-04
# Epoch 346/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6618e-05 - mean_squared_error: 8.3608e-06 - learning_rate: 7.1450e-04
# Epoch 347/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5617e-05 - mean_squared_error: 7.3905e-06 - learning_rate: 7.1379e-04
# Epoch 348/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.5741e-05 - mean_squared_error: 7.5496e-06 - learning_rate: 7.1307e-04
# Epoch 349/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6761e-05 - mean_squared_error: 8.6032e-06 - learning_rate: 7.1236e-04
# Epoch 350/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8191e-05 - mean_squared_error: 1.0066e-05 - val_loss: 1.1139e-04 - val_mean_squared_error: 7.3273e-05 - learning_rate: 7.1165e-04
# Epoch 351/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6495e-05 - mean_squared_error: 8.3856e-06 - learning_rate: 7.1094e-04
# Epoch 352/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8862e-05 - mean_squared_error: 1.0784e-05 - learning_rate: 7.1023e-04
# Epoch 353/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8093e-05 - mean_squared_error: 1.0025e-05 - learning_rate: 7.0952e-04
# Epoch 354/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8256e-05 - mean_squared_error: 1.0207e-05 - learning_rate: 7.0881e-04
# Epoch 355/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1926e-05 - mean_squared_error: 1.3874e-05 - learning_rate: 7.0810e-04
# Epoch 356/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9380e-05 - mean_squared_error: 1.1320e-05 - learning_rate: 7.0739e-04
# Epoch 357/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9774e-05 - mean_squared_error: 1.1726e-05 - learning_rate: 7.0668e-04
# Epoch 358/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.0175e-05 - mean_squared_error: 1.2137e-05 - learning_rate: 7.0598e-04
# Epoch 359/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0287e-05 - mean_squared_error: 1.2259e-05 - learning_rate: 7.0527e-04
# Epoch 360/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4129e-05 - mean_squared_error: 1.6102e-05 - val_loss: 1.1615e-04 - val_mean_squared_error: 7.8111e-05 - learning_rate: 7.0456e-04
# Epoch 361/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1176e-05 - mean_squared_error: 1.3123e-05 - learning_rate: 7.0386e-04
# Epoch 362/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0913e-05 - mean_squared_error: 1.2866e-05 - learning_rate: 7.0316e-04
# Epoch 363/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0196e-05 - mean_squared_error: 1.2153e-05 - learning_rate: 7.0245e-04
# Epoch 364/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9431e-05 - mean_squared_error: 1.1395e-05 - learning_rate: 7.0175e-04
# Epoch 365/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9636e-05 - mean_squared_error: 1.1616e-05 - learning_rate: 7.0105e-04
# Epoch 366/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0264e-05 - mean_squared_error: 1.2247e-05 - learning_rate: 7.0035e-04
# Epoch 367/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0542e-05 - mean_squared_error: 1.2531e-05 - learning_rate: 6.9965e-04
# Epoch 368/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7929e-05 - mean_squared_error: 9.9157e-06 - learning_rate: 6.9895e-04
# Epoch 369/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5825e-05 - mean_squared_error: 7.8323e-06 - learning_rate: 6.9825e-04
# Epoch 370/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7527e-05 - mean_squared_error: 9.5703e-06 - val_loss: 1.1551e-04 - val_mean_squared_error: 7.7553e-05 - learning_rate: 6.9755e-04
# Epoch 371/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9329e-05 - mean_squared_error: 1.1385e-05 - learning_rate: 6.9685e-04
# Epoch 372/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2516e-05 - mean_squared_error: 1.4598e-05 - learning_rate: 6.9616e-04
# Epoch 373/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9289e-05 - mean_squared_error: 1.1364e-05 - learning_rate: 6.9546e-04
# Epoch 374/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0409e-05 - mean_squared_error: 1.2486e-05 - learning_rate: 6.9476e-04
# Epoch 375/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0764e-05 - mean_squared_error: 1.2850e-05 - learning_rate: 6.9407e-04
# Epoch 376/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9496e-05 - mean_squared_error: 1.1582e-05 - learning_rate: 6.9338e-04
# Epoch 377/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6343e-05 - mean_squared_error: 8.4434e-06 - learning_rate: 6.9268e-04
# Epoch 378/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8114e-05 - mean_squared_error: 1.0238e-05 - learning_rate: 6.9199e-04
# Epoch 379/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6973e-05 - mean_squared_error: 9.1298e-06 - learning_rate: 6.9130e-04
# Epoch 380/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9954e-05 - mean_squared_error: 1.2120e-05 - val_loss: 1.1681e-04 - val_mean_squared_error: 7.8989e-05 - learning_rate: 6.9061e-04
# Epoch 381/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2070e-05 - mean_squared_error: 1.4248e-05 - learning_rate: 6.8992e-04
# Epoch 382/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9654e-05 - mean_squared_error: 1.1823e-05 - learning_rate: 6.8923e-04
# Epoch 383/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8471e-05 - mean_squared_error: 1.0641e-05 - learning_rate: 6.8854e-04
# Epoch 384/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9521e-05 - mean_squared_error: 1.1709e-05 - learning_rate: 6.8785e-04
# Epoch 385/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2863e-05 - mean_squared_error: 1.5049e-05 - learning_rate: 6.8716e-04
# Epoch 386/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2025e-05 - mean_squared_error: 1.4214e-05 - learning_rate: 6.8647e-04
# Epoch 387/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1178e-05 - mean_squared_error: 1.3374e-05 - learning_rate: 6.8579e-04
# Epoch 388/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8844e-05 - mean_squared_error: 1.1024e-05 - learning_rate: 6.8510e-04
# Epoch 389/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7219e-05 - mean_squared_error: 9.4159e-06 - learning_rate: 6.8442e-04
# Epoch 390/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7354e-05 - mean_squared_error: 9.5763e-06 - val_loss: 1.1234e-04 - val_mean_squared_error: 7.4569e-05 - learning_rate: 6.8373e-04
# Epoch 391/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5056e-05 - mean_squared_error: 7.2938e-06 - learning_rate: 6.8305e-04
# Epoch 392/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4783e-05 - mean_squared_error: 7.0610e-06 - learning_rate: 6.8236e-04
# Epoch 393/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5507e-05 - mean_squared_error: 7.8301e-06 - learning_rate: 6.8168e-04
# Epoch 394/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4697e-05 - mean_squared_error: 7.0348e-06 - learning_rate: 6.8100e-04
# Epoch 395/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4316e-05 - mean_squared_error: 6.6924e-06 - learning_rate: 6.8032e-04
# Epoch 396/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4485e-05 - mean_squared_error: 6.8999e-06 - learning_rate: 6.7964e-04
# Epoch 397/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4650e-05 - mean_squared_error: 7.0963e-06 - learning_rate: 6.7896e-04
# Epoch 398/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4527e-05 - mean_squared_error: 6.9979e-06 - learning_rate: 6.7828e-04
# Epoch 399/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8165e-05 - mean_squared_error: 1.0671e-05 - learning_rate: 6.7760e-04
# Epoch 400/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8273e-05 - mean_squared_error: 1.0794e-05 - val_loss: 1.1938e-04 - val_mean_squared_error: 8.1902e-05 - learning_rate: 6.7692e-04
# Epoch 401/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8261e-05 - mean_squared_error: 1.0802e-05 - learning_rate: 6.7625e-04
# Epoch 402/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6383e-05 - mean_squared_error: 8.9311e-06 - learning_rate: 6.7557e-04
# Epoch 403/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6610e-05 - mean_squared_error: 9.1625e-06 - learning_rate: 6.7490e-04
# Epoch 404/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5833e-05 - mean_squared_error: 8.4018e-06 - learning_rate: 6.7422e-04
# Epoch 405/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5358e-05 - mean_squared_error: 7.9530e-06 - learning_rate: 6.7355e-04
# Epoch 406/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5899e-05 - mean_squared_error: 8.5143e-06 - learning_rate: 6.7287e-04
# Epoch 407/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.5579e-05 - mean_squared_error: 8.2198e-06 - learning_rate: 6.7220e-04
# Epoch 408/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7083e-05 - mean_squared_error: 9.7497e-06 - learning_rate: 6.7153e-04
# Epoch 409/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8986e-05 - mean_squared_error: 1.1666e-05 - learning_rate: 6.7086e-04
# Epoch 410/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0146e-05 - mean_squared_error: 1.2821e-05 - val_loss: 1.1761e-04 - val_mean_squared_error: 8.0271e-05 - learning_rate: 6.7019e-04
# Epoch 411/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1075e-05 - mean_squared_error: 1.3730e-05 - learning_rate: 6.6952e-04
# Epoch 412/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7177e-05 - mean_squared_error: 9.8198e-06 - learning_rate: 6.6885e-04
# Epoch 413/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6430e-05 - mean_squared_error: 9.0858e-06 - learning_rate: 6.6818e-04
# Epoch 414/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6475e-05 - mean_squared_error: 9.1459e-06 - learning_rate: 6.6751e-04
# Epoch 415/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5763e-05 - mean_squared_error: 8.4530e-06 - learning_rate: 6.6684e-04
# Epoch 416/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9041e-05 - mean_squared_error: 1.1753e-05 - learning_rate: 6.6617e-04
# Epoch 417/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6546e-05 - mean_squared_error: 9.2586e-06 - learning_rate: 6.6551e-04
# Epoch 418/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8226e-05 - mean_squared_error: 1.0952e-05 - learning_rate: 6.6484e-04
# Epoch 419/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9678e-05 - mean_squared_error: 1.2414e-05 - learning_rate: 6.6418e-04
# Epoch 420/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7603e-05 - mean_squared_error: 1.0365e-05 - val_loss: 1.1649e-04 - val_mean_squared_error: 7.9267e-05 - learning_rate: 6.6351e-04
# Epoch 421/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8105e-05 - mean_squared_error: 1.0879e-05 - learning_rate: 6.6285e-04
# Epoch 422/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6894e-05 - mean_squared_error: 9.6745e-06 - learning_rate: 6.6219e-04
# Epoch 423/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7842e-05 - mean_squared_error: 1.0636e-05 - learning_rate: 6.6153e-04
# Epoch 424/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9809e-05 - mean_squared_error: 1.2616e-05 - learning_rate: 6.6086e-04
# Epoch 425/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.8512e-05 - mean_squared_error: 1.1326e-05 - learning_rate: 6.6020e-04
# Epoch 426/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6532e-05 - mean_squared_error: 9.3349e-06 - learning_rate: 6.5954e-04
# Epoch 427/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5275e-05 - mean_squared_error: 8.0867e-06 - learning_rate: 6.5888e-04
# Epoch 428/1000
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5835e-05 - mean_squared_error: 8.6745e-06 - learning_rate: 6.5822e-04
# Epoch 429/1000
# 11/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6972e-05 - mean_squared_error: 9.8224e-06

# %% [markdown]
# $N^0 $ of samples = 4000

# %%
import numpy as np
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Add
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

Training = True

coeff = 1e-7
n_neurons = 256
n_splits = 4
n_sample = 4000

model_lf = load_model(f'./models/model_10resolution_64000samples_1.keras')

# Load the data
X_train_params = np.loadtxt('../../data/50-25-10/X_train_50resolution.csv', delimiter=',')[:n_sample,:]
X_train_pod = model_lf(X_train_params).numpy()[:n_sample,:]
y_train = np.loadtxt('../../data/50-25-10/y_train_50resolution.csv', delimiter=',')[:n_sample,:]

print(np.mean((X_train_pod - y_train)**2))

print(y_train)

X_test_params = np.loadtxt('../../data/50-25-10/X_test_50resolution.csv', delimiter=',')
X_test_pod = model_lf(X_test_params).numpy()
y_test = np.loadtxt('../../data/50-25-10/y_test_50resolution.csv', delimiter=',')

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch > 1000:
        return lr*(epoch)/(1+epoch)
    else:
        return max(lr * 0.999, 1e-7)
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 1

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(combined)
output = Dense(25, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

for train_index, val_index in kf.split(X_train_params):

    print(f"Training fold {fold_var}...")

    # Splitting the data into training and validation sets
    X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
    X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    # Compile the model
    initial_learning_rate = 0.001
    optimizer = Adam(learning_rate=initial_learning_rate)
    model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

    # Define the learning rate scheduler callback
    lr_scheduler = LearningRateScheduler(scheduler)

    # Train the model
    history = model.fit([X_train_params_k, X_train_pod_k], y_train_k,
                        epochs=1000,
                        batch_size=64,
                        validation_data=([X_val_params_k, X_val_pod_k], y_val_k),
                        validation_freq=10,
                        callbacks=[lr_scheduler])
    
    # Save the model for each fold
    model.save(f'./models/model_2step_50-10resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

    # Increment the fold number
    fold_var += 1

# %% [markdown]
# $N^0 $ of samples = 8000

# %%
import numpy as np
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Add
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

Training = True

coeff = 1e-8
n_neurons = 256
n_splits = 4
n_sample = 8000

model_lf = load_model(f'./models/model_10resolution_64000samples_1.keras')

# Load the data
X_train_params = np.loadtxt('../../data/50-25-10/X_train_50resolution.csv', delimiter=',')[:n_sample,:]
X_train_pod = model_lf(X_train_params).numpy()[:n_sample,:]
y_train = np.loadtxt('../../data/50-25-10/y_train_50resolution.csv', delimiter=',')[:n_sample,:]

print(np.mean((X_train_pod - y_train)**2))

print(y_train)

X_test_params = np.loadtxt('../../data/50-25-10/X_test_50resolution.csv', delimiter=',')
X_test_pod = model_lf(X_test_params).numpy()
y_test = np.loadtxt('../../data/50-25-10/y_test_50resolution.csv', delimiter=',')

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch > 1000:
        return lr*(epoch)/(1+epoch)
    else:
        return max(lr * 0.99, 1e-7)
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 1

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(combined)
output = Dense(25, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

for train_index, val_index in kf.split(X_train_params):

    print(f"Training fold {fold_var}...")

    # Splitting the data into training and validation sets
    X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
    X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    # Compile the model
    initial_learning_rate = 0.001
    optimizer = Adam(learning_rate=initial_learning_rate)
    model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

    # Define the learning rate scheduler callback
    lr_scheduler = LearningRateScheduler(scheduler)

    # Train the model
    history = model.fit([X_train_params_k, X_train_pod_k], y_train_k,
                        epochs=1000,
                        batch_size=64,
                        validation_data=([X_val_params_k, X_val_pod_k], y_val_k),
                        validation_freq=10,
                        callbacks=[lr_scheduler])
    
    # Save the model for each fold
    model.save(f'./models/model_2step_50-10resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

    # Increment the fold number
    fold_var += 1

# %% [markdown]
# $N^0 $ of samples = 16000

# %%
import numpy as np
from keras.models import Model, Sequential, load_model
from keras.layers import Input, Dense, Add
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

Training = True

coeff = 1e-8
n_neurons = 256
n_splits = 4
n_sample = 16000

model_lf = load_model(f'./models/model_10resolution_64000samples_1.keras')

# Load the data
X_train_params = np.loadtxt('../../data/50-25-10/X_train_50resolution.csv', delimiter=',')[:n_sample,:]
X_train_pod = model_lf(X_train_params).numpy()[:n_sample,:]
y_train = np.loadtxt('../../data/50-25-10/y_train_50resolution.csv', delimiter=',')[:n_sample,:]

print(np.mean((X_train_pod - y_train)**2))

print(y_train)

X_test_params = np.loadtxt('../../data/50-25-10/X_test_50resolution.csv', delimiter=',')
X_test_pod = model_lf(X_test_params).numpy()
y_test = np.loadtxt('../../data/50-25-10/y_test_50resolution.csv', delimiter=',')

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch > 1000:
        return lr*(epoch)/(1+epoch)
    else:
        return max(lr * 0.99, 1e-7)
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 1

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(combined)
output = Dense(25, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

for train_index, val_index in kf.split(X_train_params):

    print(f"Training fold {fold_var}...")

    # Splitting the data into training and validation sets
    X_train_params_k, X_val_params_k = X_train_params[train_index], X_train_params[val_index]
    X_train_pod_k, X_val_pod_k = X_train_pod[train_index], X_train_pod[val_index]
    y_train_k, y_val_k = y_train[train_index], y_train[val_index]

    # Compile the model
    initial_learning_rate = 0.001
    optimizer = Adam(learning_rate=initial_learning_rate)
    model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

    # Define the learning rate scheduler callback
    lr_scheduler = LearningRateScheduler(scheduler)

    # Train the model
    history = model.fit([X_train_params_k, X_train_pod_k], y_train_k,
                        epochs=1000,
                        batch_size=64,
                        validation_data=([X_val_params_k, X_val_pod_k], y_val_k),
                        validation_freq=10,
                        callbacks=[lr_scheduler])
    
    # Save the model for each fold
    model.save(f'./models/model_2step_50-10resolution_{n_sample}samples_{fold_var}_coeff{coeff}.keras')

    # Increment the fold number
    fold_var += 1

# %%
model = load_model(f'./models/model_50-10resolution_{n_sample}samples_4.keras')
model((X_test_params,X_test_pod)).numpy()
# Out:
# array([[0.9412804 , 0.96021557, 0.9310102 , ..., 0.11300899, 0.10804499,
#         0.08837804],
#        [0.9211987 , 0.9238984 , 0.9598889 , ..., 0.06384155, 0.06865404,
#         0.08434081],
#        [0.9307978 , 0.9188586 , 0.8705659 , ..., 0.07316414, 0.15586762,
#         0.1932146 ],
#        ...,
#        [0.9303663 , 0.8583942 , 0.8404265 , ..., 0.14173916, 0.07137661,
#         0.06788851],
#        [0.95010877, 0.92889416, 0.9032178 , ..., 0.09457538, 0.10062466,
#         0.08408783],
#        [0.8260754 , 0.74899834, 0.85366315, ..., 0.1172493 , 0.10054297,
#         0.10147938]], dtype=float32)
