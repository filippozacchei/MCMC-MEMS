# %% [markdown]
# # Create a surrogate model for our problem
# We will use first a physical approximation of the solution using Forward Euler
# We will then refine the solution using a NN in a multi level approach

# %%
import numpy as np
import matplotlib as plt
import os 
import timeit
from scipy.stats import uniform
from numba import jit 
import tensorflow as tf

# %% [markdown]
# ### Create physical coarse approximation of the solution

# %% [markdown]
# Define help function to compute the total stiffness

# %%
@jit(nopython=True) # Use nopython mode for best performance and simplest compilation
def compute_stiffness(w, th , E , l1 , l2 , oe): 
    """
    Inputs:
    w - Beam width
    th - Beam thickness 
    E - Young's modulus of the beam material
    l1 - Length of the longer beams
    l2 - Length of the shorter beams
    oe - Overetch affecting the effective width of the beam

     Output:
     kTotal - Total stiffness of the folded beam structure
    """
    effectiveWidth = w - 2*oe
    J = (1/12) * th * effectiveWidth**3
    #Stiffness of individual beams based on their length
    k1 = 12 * E * J / (l1**3 * 4)
    k2 = 12 * E * J / (l2**3 * 2)
    kTotal = 2 / (1/k1 + 1/k2)
    
    return kTotal

# %%
@jit(nopython=True)
def fringing_coeff( G, W ,L):
    return (1+ G/np.pi/W + G/np.pi/W*np.log(2*np.pi*W/G))*(1+ G/np.pi/L + G/np.pi/L*np.log(2*np.pi*L/G))

# %%
@jit(nopython=True)
def coarse_model(params):
    """
    - Inputs:
    - parameters[0] : Overetch 
    - parameters[1] : Offset
    - parameters[2] : Thickness

    - Output:
    - C : An array containing the computed difference of capacitance 
    """
    # Time parameters
    t0 = 0                    # Initial time.
    tf = 0.0015-1e-5          # Final time.
    dt =1e-5                # Time step size.

    # Stiffness parameters
    l1 = 221.4*1e-6              # Lenght of the longer beam 
    l2 = 110*1e-6            # Length of the shorted beam
    E  = 160*1e9               # Young Modulus 
    w  = 2.8*1e-6              # Width 

    # Force parameters 
    phi = lambda t: 0.9*(1-np.cos(2*np.pi*2500*t)) if t < 2/2500 else 0 # Voltage in the right electrodes
    s   = 101*1e-6             # param for the surface 
    dp  =1.2*1e-6                # Distance from the plates with Overetch and Offset = 0 

    # Mass parameters
    rho = 2320                 # Density of the mass.
    A   = 84*1e-9              # Area of the component

    # Damping parameters 
    alpha = 31440            # Damping coefficient alpha. 31400
    beta  =  0               # Damping coeff beta 

    # Input Parameters 
    oe = params[0]*1e-6
    of = params[1]*1e-6
    th = params[2]*1e-6 # ricorda di rimettere 6
   
    eps0 = 8.854*1e-12       # Dielectric permittivity constant
    eps1 = 1.000             # Relative dielectric permittivity of air.

    # Compute the distance between the faces of electrodes and the sensor
    dl = dp+2*oe+of
    dr = dp+2*oe-of
    # Compute the surface of the electrode 
    S = th * (s - 2*oe) * 10  # multiply by ten since we have 10 condensators
    
    # Initial conditions
    u0 = 0  # Initial displacement
    v0 = 0  # Initial velocity
    N = int((tf - t0) / dt)

    # Initialization
    u = np.zeros((N+1))  # displacement
    v = np.zeros((N+1))  # velocity
    C = np.zeros((N+1))  # capacitance
    u[0] = u0
    v[0] = v0
    C[0] = eps1*eps0*S*(1/(dr)*fringing_coeff( dr, s-2*oe ,th) - 1/(dl)*fringing_coeff( dl, s-2*oe ,th))

    # Compute the stiffness
    k = compute_stiffness(w, th , E , l1 , l2 , oe) 
   
    # Compute mass
    m = rho * A * th
    # Compute Damping 
    damp = alpha* m + beta* k

    # Precompute phi values to avoid redundant computation
    k1 =  0.5 * eps0 * eps1 * S
    k2 = eps1*eps0*S
    F_values = np.array([phi(n * dt) for n in range(N)])**2 * k1

    # Time-stepping loop using Forward Euler scheme
    for n in range(N) :
        u_n = u[n]
        v_n = v[n]
        u_new = u_n + dt * v_n
        # Compute the value of the input voltage at time t = n*dt 
        F = F_values[n]/((dr-u_n)**2)
        v[n+1] = v_n + dt * ( F - damp*v_n - k*u_n )/m
        # Compute the difference of capacitance
        C[n+1] = k2*(1/(dr-u_new)*fringing_coeff( dr-u_new, s-2*oe ,th) - 1/(dl+u_new)*fringing_coeff( dl+u_new, s-2*oe ,th))
        u[n+1] = u_new

    return C*1e15*1.02

# %% [markdown]
# # Quality of the solution choosing a subsample of the coarse solution

# %% [markdown]
# Select the true samples on which we want to test the corse model, compare them with the coarse model, choosing only one out od three samples

# %%
# Standard library imports
import sys
# Local module imports
sys.path.append('../../src/SurrogateModeling')
sys.path.append('../../src/InverseProblems')
sys.path.append('../../src/utils')
from utils import * 

# Surrogate Model Configurations
CONFIGURATION_I = './config_I.json'
data_processor_I = preprocessing(CONFIGURATION_I)

# Extract test data 
X_values, y_values = data_processor_I.X_test, data_processor_I.y_test

# Which sample of the training set do wou want to take as experimental input?
sample = [5,11, 22, 38, 60]

# Select a true sample for testing
x_true, y_true = X_values[sample], y_values[sample]
print('        Overetch,   Offset,   Thickness')
x_true
# Out:
#         Overetch,   Offset,   Thickness
# array([[ 2.3053600e-01, -6.8871000e-02,  3.0351452e+01],
#        [ 4.5057900e-01, -4.4200000e-04,  2.9471304e+01],
#        [ 1.5078200e-01, -6.1468000e-02,  3.0962383e+01],
#        [ 2.6249600e-01, -2.7814000e-02,  2.9626475e+01],
#        [ 4.6478700e-01, -3.4692000e-01,  2.9295773e+01]])

# %% [markdown]
# Perform comparisons with different types of inputs of parameters

# %%
ratio = []
for index, x in enumerate(x_true):
    print('The parameters used are:' , x)
    res = coarse_model(x)#[1:150:3]
    x3 = np.linspace(0,150,150)
    x = np.linspace(0,150,150)
    plt.plot(x3, res)
    plt.plot(x,y_true[index], color = 'r', alpha =0.8)
    plt.legend(['Coarse Model', 'True Solutions'])
    plt.show()
    ratio.append(  np.linalg.norm((res - y_true[index]), ord=1)  / np.linalg.norm(( y_true[index]), ord=1) )

#plt.plot(y_true[-1]-res)
#plt.show()
print('Mean absolute percentage error for the simulations are:\n', np.array(ratio) )
# Out:
# The parameters used are: [ 0.230536 -0.068871 30.351452]
# The parameters used are: [ 4.5057900e-01 -4.4200000e-04  2.9471304e+01]
# The parameters used are: [ 0.150782 -0.061468 30.962383]
# The parameters used are: [ 2.6249600e-01 -2.7814000e-02  2.9626475e+01]
# The parameters used are: [ 0.464787 -0.34692  29.295773]
# Mean absolute percentage error for the simulations are:
#  [0.01478697 0.06420755 0.01865394 0.03882397 0.00342058]

# %% [markdown]
# # Multi-Fidelity NN

# %%
import numpy as np
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Input, Add, Dense, Concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, LearningRateScheduler

from sklearn.model_selection import KFold

from tensorflow.keras.regularizers import l2

# %%
# Collecting traing and Testing Data
X_train = data_processor_I.X_train
X_test = data_processor_I.X_test
y_train = data_processor_I.y_train
y_test = data_processor_I.y_test

# %%
coarse_y_train = []
coarse_y_test = []
for x in X_train:  
    coarse_y_train.append(coarse_model(x))
for x in X_test:
    coarse_y_test.append(coarse_model(x))

len(coarse_y_train)
# Out:
# 640

# %%
X_train_scaled = data_processor_I.scaler.fit_transform(X_train)
X_test_scaled = data_processor_I.scaler.transform(X_test)
y_train_scaled = data_processor_I.y_train
y_test_scaled = data_processor_I.y_test

# %%
Training = True

coeff = 1e-12
n_neurons = 256
n_splits = 4

# Load the data
X_train_params = X_train_scaled
X_train_pod = np.array(coarse_y_train)
y_train = y_train_scaled

X_test_params = X_test_scaled
X_test_pod = np.array(coarse_y_test)
y_test = y_test_scaled

print(y_train.shape)
print(X_train_params.shape)
print(X_train_pod.shape)

print(y_test.shape)
print(X_test_params.shape)
print(X_test_pod.shape)

def scheduler(epoch, lr):
        if epoch > 10 and epoch < 900:
                return lr*0.99
        elif epoch >= 900:
                return lr*(1+0.1*epoch)/(1.1+0.1*epoch)
        else:
                return lr
    
# Setting up K-Fold Cross-Validation
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Cross-validation loop
fold_var = 1

# Define the three branches of the model
input_params = Input(shape=(X_train_params.shape[1],))
input_pod = Input(shape=(X_train_pod.shape[1],))

# Define the first branch (parameters)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(input_params)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(coeff))(x1)
x1 = Dense(n_neurons, activation='linear', kernel_regularizer=l2(coeff))(x1)

# Define the second branch (POD)
x2 = Dense(n_neurons, activation='linear', kernel_regularizer=l2(coeff))(input_pod)

# # Define the second branch (POD)
# x3 = Dense(n_neurons, activation='gelu', kernel_regularizer=l2(w))(input_nn)

# Combine the outputs of the three branches
combined = Add()([x1,x2])
combined = Dense(n_neurons, activation='linear', kernel_regularizer=l2(coeff))(combined)
output = Dense(150, activation='linear', kernel_regularizer=l2(coeff))(combined)

# Create the model
model = Model(inputs=[input_params,input_pod], outputs=output)

# Compile the model
initial_learning_rate = 0.001
optimizer = Adam(learning_rate=initial_learning_rate)
model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_squared_error'])

# Define the learning rate scheduler callback
lr_scheduler = LearningRateScheduler(scheduler)

# Train the model
history = model.fit([X_train_params, X_train_pod], y_train,
                    epochs=10000,
                    batch_size=data_processor_I.config['BATCH_SIZE']//150,
                    validation_data=([X_test_params, X_test_pod], y_test),
                    validation_freq=10,
                    callbacks=[lr_scheduler])

# Save the model for each fold
model.save(f'./models/model_euler_mf.keras')

# Increment the fold number
fold_var += 1
# Out:
# (640, 150)
# (640, 3)
# (640, 150)
# (160, 150)
# (160, 3)
# (160, 150)
# Epoch 1/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1782.9644 - mean_squared_error: 1782.9644 - learning_rate: 0.0010
# Epoch 2/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.8798 - mean_squared_error: 14.8798 - learning_rate: 0.0010
# Epoch 3/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3528 - mean_squared_error: 1.3528 - learning_rate: 0.0010
# Epoch 4/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5251 - mean_squared_error: 0.5251 - learning_rate: 0.0010
# Epoch 5/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5307 - mean_squared_error: 0.5307 - learning_rate: 0.0010
# Epoch 6/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3294 - mean_squared_error: 0.3294 - learning_rate: 0.0010
# Epoch 7/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2281 - mean_squared_error: 0.2281 - learning_rate: 0.0010
# Epoch 8/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1109 - mean_squared_error: 0.1109 - learning_rate: 0.0010
# Epoch 9/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1247 - mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 10/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1622 - mean_squared_error: 0.1622 - val_loss: 0.1952 - val_mean_squared_error: 0.1952 - learning_rate: 0.0010
# Epoch 11/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2970 - mean_squared_error: 0.2970 - learning_rate: 0.0010
# Epoch 12/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2954 - mean_squared_error: 0.2954 - learning_rate: 9.9000e-04
# Epoch 13/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1118 - mean_squared_error: 0.1118 - learning_rate: 9.8010e-04
# Epoch 14/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3836 - mean_squared_error: 0.3836 - learning_rate: 9.7030e-04
# Epoch 15/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8181 - mean_squared_error: 0.8181 - learning_rate: 9.6060e-04
# Epoch 16/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5332 - mean_squared_error: 0.5332 - learning_rate: 9.5099e-04
# Epoch 17/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7451 - mean_squared_error: 2.7451 - learning_rate: 9.4148e-04
# Epoch 18/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0605 - mean_squared_error: 1.0605 - learning_rate: 9.3207e-04
# Epoch 19/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2346 - mean_squared_error: 0.2346 - learning_rate: 9.2274e-04
# Epoch 20/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5458 - mean_squared_error: 0.5458 - val_loss: 0.2614 - val_mean_squared_error: 0.2614 - learning_rate: 9.1352e-04
# Epoch 21/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2622 - mean_squared_error: 0.2622 - learning_rate: 9.0438e-04
# Epoch 22/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2486 - mean_squared_error: 0.2486 - learning_rate: 8.9534e-04
# Epoch 23/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0351 - mean_squared_error: 1.0351 - learning_rate: 8.8638e-04
# Epoch 24/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7258 - mean_squared_error: 1.7258 - learning_rate: 8.7752e-04
# Epoch 25/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4843 - mean_squared_error: 4.4843 - learning_rate: 8.6875e-04
# Epoch 26/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6452 - mean_squared_error: 0.6452 - learning_rate: 8.6006e-04
# Epoch 27/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0394 - mean_squared_error: 1.0394 - learning_rate: 8.5146e-04
# Epoch 28/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2731 - mean_squared_error: 0.2731 - learning_rate: 8.4294e-04
# Epoch 29/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1205 - mean_squared_error: 0.1205 - learning_rate: 8.3451e-04
# Epoch 30/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5526 - mean_squared_error: 1.5526 - val_loss: 0.2597 - val_mean_squared_error: 0.2597 - learning_rate: 8.2617e-04
# Epoch 31/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1839 - mean_squared_error: 0.1839 - learning_rate: 8.1791e-04
# Epoch 32/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1858 - mean_squared_error: 0.1858 - learning_rate: 8.0973e-04
# Epoch 33/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0801 - mean_squared_error: 0.0801 - learning_rate: 8.0163e-04
# Epoch 34/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0552 - mean_squared_error: 0.0552 - learning_rate: 7.9361e-04
# Epoch 35/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0400 - mean_squared_error: 0.0400 - learning_rate: 7.8568e-04
# Epoch 36/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1258 - mean_squared_error: 0.1258 - learning_rate: 7.7782e-04
# Epoch 37/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3081 - mean_squared_error: 0.3081 - learning_rate: 7.7004e-04
# Epoch 38/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5874 - mean_squared_error: 1.5874 - learning_rate: 7.6234e-04
# Epoch 39/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7633 - mean_squared_error: 1.7633 - learning_rate: 7.5472e-04
# Epoch 40/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8512 - mean_squared_error: 0.8512 - val_loss: 5.9736 - val_mean_squared_error: 5.9736 - learning_rate: 7.4717e-04
# Epoch 41/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8261 - mean_squared_error: 1.8261 - learning_rate: 7.3970e-04
# Epoch 42/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1629 - mean_squared_error: 0.1629 - learning_rate: 7.3230e-04
# Epoch 43/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0440 - mean_squared_error: 0.0440 - learning_rate: 7.2498e-04
# Epoch 44/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0670 - mean_squared_error: 0.0670 - learning_rate: 7.1773e-04
# Epoch 45/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2505 - mean_squared_error: 1.2505 - learning_rate: 7.1055e-04
# Epoch 46/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9210 - mean_squared_error: 0.9210 - learning_rate: 7.0345e-04
# Epoch 47/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2517 - mean_squared_error: 0.2517 - learning_rate: 6.9641e-04
# Epoch 48/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2456 - mean_squared_error: 0.2456 - learning_rate: 6.8945e-04
# Epoch 49/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1466 - mean_squared_error: 0.1466 - learning_rate: 6.8255e-04
# Epoch 50/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0767 - mean_squared_error: 0.0767 - val_loss: 0.0297 - val_mean_squared_error: 0.0297 - learning_rate: 6.7573e-04
# Epoch 51/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - learning_rate: 6.6897e-04
# Epoch 52/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2302 - mean_squared_error: 0.2302 - learning_rate: 6.6228e-04
# Epoch 53/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0798 - mean_squared_error: 0.0798 - learning_rate: 6.5566e-04
# Epoch 54/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3360 - mean_squared_error: 0.3360 - learning_rate: 6.4910e-04
# Epoch 55/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2607 - mean_squared_error: 0.2607 - learning_rate: 6.4261e-04
# Epoch 56/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1060 - mean_squared_error: 0.1060 - learning_rate: 6.3619e-04
# Epoch 57/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3712 - mean_squared_error: 0.3712 - learning_rate: 6.2982e-04
# Epoch 58/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0917 - mean_squared_error: 0.0917 - learning_rate: 6.2353e-04
# Epoch 59/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0745 - mean_squared_error: 0.0745 - learning_rate: 6.1729e-04
# Epoch 60/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1460 - mean_squared_error: 0.1460 - val_loss: 0.1338 - val_mean_squared_error: 0.1338 - learning_rate: 6.1112e-04
# Epoch 61/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - learning_rate: 6.0501e-04
# Epoch 62/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0897 - mean_squared_error: 0.0897 - learning_rate: 5.9896e-04
# Epoch 63/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3598 - mean_squared_error: 1.3598 - learning_rate: 5.9297e-04
# Epoch 64/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5823 - mean_squared_error: 5.5823 - learning_rate: 5.8704e-04
# Epoch 65/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3935 - mean_squared_error: 0.3935 - learning_rate: 5.8117e-04
# Epoch 66/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0754 - mean_squared_error: 0.0754 - learning_rate: 5.7535e-04
# Epoch 67/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2765 - mean_squared_error: 0.2765 - learning_rate: 5.6960e-04
# Epoch 68/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1333 - mean_squared_error: 0.1333 - learning_rate: 5.6391e-04
# Epoch 69/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0627 - mean_squared_error: 0.0627 - learning_rate: 5.5827e-04
# Epoch 70/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0875 - mean_squared_error: 0.0875 - val_loss: 0.0518 - val_mean_squared_error: 0.0518 - learning_rate: 5.5268e-04
# Epoch 71/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9305 - mean_squared_error: 0.9305 - learning_rate: 5.4716e-04
# Epoch 72/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5168 - mean_squared_error: 3.5168 - learning_rate: 5.4169e-04
# Epoch 73/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9829 - mean_squared_error: 3.9829 - learning_rate: 5.3627e-04
# Epoch 74/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6103 - mean_squared_error: 0.6103 - learning_rate: 5.3091e-04
# Epoch 75/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1323 - mean_squared_error: 2.1323 - learning_rate: 5.2560e-04
# Epoch 76/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3110 - mean_squared_error: 5.3110 - learning_rate: 5.2034e-04
# Epoch 77/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2180 - mean_squared_error: 1.2180 - learning_rate: 5.1514e-04
# Epoch 78/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1244 - mean_squared_error: 0.1244 - learning_rate: 5.0999e-04
# Epoch 79/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - learning_rate: 5.0489e-04
# Epoch 80/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0525 - mean_squared_error: 0.0525 - val_loss: 0.1480 - val_mean_squared_error: 0.1480 - learning_rate: 4.9984e-04
# Epoch 81/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0725 - mean_squared_error: 0.0725 - learning_rate: 4.9484e-04
# Epoch 82/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - learning_rate: 4.8989e-04
# Epoch 83/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - learning_rate: 4.8499e-04
# Epoch 84/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - learning_rate: 4.8014e-04
# Epoch 85/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - learning_rate: 4.7534e-04
# Epoch 86/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0822 - mean_squared_error: 0.0822 - learning_rate: 4.7059e-04
# Epoch 87/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0855 - mean_squared_error: 0.0855 - learning_rate: 4.6588e-04
# Epoch 88/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1474 - mean_squared_error: 0.1474 - learning_rate: 4.6122e-04
# Epoch 89/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3049 - mean_squared_error: 0.3049 - learning_rate: 4.5661e-04
# Epoch 90/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0849 - val_mean_squared_error: 0.0849 - learning_rate: 4.5204e-04
# Epoch 91/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0521 - mean_squared_error: 0.0521 - learning_rate: 4.4752e-04
# Epoch 92/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0515 - mean_squared_error: 0.0515 - learning_rate: 4.4305e-04
# Epoch 93/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - learning_rate: 4.3862e-04
# Epoch 94/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - learning_rate: 4.3423e-04
# Epoch 95/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - learning_rate: 4.2989e-04
# Epoch 96/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - learning_rate: 4.2559e-04
# Epoch 97/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0447 - mean_squared_error: 0.0447 - learning_rate: 4.2133e-04
# Epoch 98/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - learning_rate: 4.1712e-04
# Epoch 99/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - learning_rate: 4.1295e-04
# Epoch 100/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - learning_rate: 4.0882e-04
# Epoch 101/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - learning_rate: 4.0473e-04
# Epoch 102/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - learning_rate: 4.0068e-04
# Epoch 103/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0456 - mean_squared_error: 0.0456 - learning_rate: 3.9668e-04
# Epoch 104/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - learning_rate: 3.9271e-04
# Epoch 105/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - learning_rate: 3.8878e-04
# Epoch 106/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - learning_rate: 3.8490e-04
# Epoch 107/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0745 - mean_squared_error: 0.0745 - learning_rate: 3.8105e-04
# Epoch 108/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2115 - mean_squared_error: 0.2115 - learning_rate: 3.7724e-04
# Epoch 109/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0911 - mean_squared_error: 0.0911 - learning_rate: 3.7346e-04
# Epoch 110/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0538 - mean_squared_error: 0.0538 - val_loss: 0.0349 - val_mean_squared_error: 0.0349 - learning_rate: 3.6973e-04
# Epoch 111/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0710 - mean_squared_error: 0.0710 - learning_rate: 3.6603e-04
# Epoch 112/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2925 - mean_squared_error: 0.2925 - learning_rate: 3.6237e-04
# Epoch 113/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1635 - mean_squared_error: 0.1635 - learning_rate: 3.5875e-04
# Epoch 114/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0659 - mean_squared_error: 0.0659 - learning_rate: 3.5516e-04
# Epoch 115/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2067 - mean_squared_error: 0.2067 - learning_rate: 3.5161e-04
# Epoch 116/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2952 - mean_squared_error: 0.2952 - learning_rate: 3.4809e-04
# Epoch 117/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0519 - mean_squared_error: 0.0519 - learning_rate: 3.4461e-04
# Epoch 118/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - learning_rate: 3.4117e-04
# Epoch 119/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0747 - mean_squared_error: 0.0747 - learning_rate: 3.3775e-04
# Epoch 120/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1742 - mean_squared_error: 0.1742 - val_loss: 0.1006 - val_mean_squared_error: 0.1006 - learning_rate: 3.3438e-04
# Epoch 121/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2588 - mean_squared_error: 0.2588 - learning_rate: 3.3103e-04
# Epoch 122/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6313 - mean_squared_error: 1.6313 - learning_rate: 3.2772e-04
# Epoch 123/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3158 - mean_squared_error: 2.3158 - learning_rate: 3.2445e-04
# Epoch 124/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8844 - mean_squared_error: 2.8844 - learning_rate: 3.2120e-04
# Epoch 125/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2948 - mean_squared_error: 0.2948 - learning_rate: 3.1799e-04
# Epoch 126/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0465 - mean_squared_error: 0.0465 - learning_rate: 3.1481e-04
# Epoch 127/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - learning_rate: 3.1166e-04
# Epoch 128/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0529 - mean_squared_error: 0.0529 - learning_rate: 3.0854e-04
# Epoch 129/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0603 - mean_squared_error: 0.0603 - learning_rate: 3.0546e-04
# Epoch 130/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - learning_rate: 3.0240e-04
# Epoch 131/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - learning_rate: 2.9938e-04
# Epoch 132/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - learning_rate: 2.9639e-04
# Epoch 133/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1722 - mean_squared_error: 0.1722 - learning_rate: 2.9342e-04
# Epoch 134/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - learning_rate: 2.9049e-04
# Epoch 135/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - learning_rate: 2.8758e-04
# Epoch 136/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0411 - mean_squared_error: 0.0411 - learning_rate: 2.8471e-04
# Epoch 137/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - learning_rate: 2.8186e-04
# Epoch 138/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - learning_rate: 2.7904e-04
# Epoch 139/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - learning_rate: 2.7625e-04
# Epoch 140/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - learning_rate: 2.7349e-04
# Epoch 141/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - learning_rate: 2.7075e-04
# Epoch 142/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1186 - mean_squared_error: 0.1186 - learning_rate: 2.6805e-04
# Epoch 143/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3930 - mean_squared_error: 0.3930 - learning_rate: 2.6537e-04
# Epoch 144/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0235 - mean_squared_error: 2.0235 - learning_rate: 2.6271e-04
# Epoch 145/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1007 - mean_squared_error: 0.1007 - learning_rate: 2.6009e-04
# Epoch 146/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0382 - mean_squared_error: 0.0382 - learning_rate: 2.5748e-04
# Epoch 147/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - learning_rate: 2.5491e-04
# Epoch 148/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - learning_rate: 2.5236e-04
# Epoch 149/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - learning_rate: 2.4984e-04
# Epoch 150/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - learning_rate: 2.4734e-04
# Epoch 151/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - learning_rate: 2.4487e-04
# Epoch 152/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - learning_rate: 2.4242e-04
# Epoch 153/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - learning_rate: 2.3999e-04
# Epoch 154/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - learning_rate: 2.3759e-04
# Epoch 155/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - learning_rate: 2.3522e-04
# Epoch 156/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - learning_rate: 2.3286e-04
# Epoch 157/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mean_squared_error: 0.0087 - learning_rate: 2.3054e-04
# Epoch 158/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - learning_rate: 2.2823e-04
# Epoch 159/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - learning_rate: 2.2595e-04
# Epoch 160/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - learning_rate: 2.2369e-04
# Epoch 161/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - learning_rate: 2.2145e-04
# Epoch 162/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - learning_rate: 2.1924e-04
# Epoch 163/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - learning_rate: 2.1705e-04
# Epoch 164/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - learning_rate: 2.1487e-04
# Epoch 165/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0922 - mean_squared_error: 0.0922 - learning_rate: 2.1273e-04
# Epoch 166/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - learning_rate: 2.1060e-04
# Epoch 167/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0378 - mean_squared_error: 0.0378 - learning_rate: 2.0849e-04
# Epoch 168/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0662 - mean_squared_error: 0.0662 - learning_rate: 2.0641e-04
# Epoch 169/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1685 - mean_squared_error: 0.1685 - learning_rate: 2.0434e-04
# Epoch 170/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0820 - mean_squared_error: 0.0820 - val_loss: 0.0332 - val_mean_squared_error: 0.0332 - learning_rate: 2.0230e-04
# Epoch 171/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - learning_rate: 2.0028e-04
# Epoch 172/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - learning_rate: 1.9827e-04
# Epoch 173/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - learning_rate: 1.9629e-04
# Epoch 174/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1856 - mean_squared_error: 0.1856 - learning_rate: 1.9433e-04
# Epoch 175/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6978 - mean_squared_error: 1.6978 - learning_rate: 1.9239e-04
# Epoch 176/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2299 - mean_squared_error: 0.2299 - learning_rate: 1.9046e-04
# Epoch 177/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0358 - mean_squared_error: 0.0358 - learning_rate: 1.8856e-04
# Epoch 178/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - learning_rate: 1.8667e-04
# Epoch 179/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - learning_rate: 1.8480e-04
# Epoch 180/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - learning_rate: 1.8296e-04
# Epoch 181/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - learning_rate: 1.8113e-04
# Epoch 182/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 1.7932e-04
# Epoch 183/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - learning_rate: 1.7752e-04
# Epoch 184/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - learning_rate: 1.7575e-04
# Epoch 185/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - learning_rate: 1.7399e-04
# Epoch 186/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - learning_rate: 1.7225e-04
# Epoch 187/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - learning_rate: 1.7053e-04
# Epoch 188/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - learning_rate: 1.6882e-04
# Epoch 189/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - learning_rate: 1.6713e-04
# Epoch 190/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - learning_rate: 1.6546e-04
# Epoch 191/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - learning_rate: 1.6381e-04
# Epoch 192/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - learning_rate: 1.6217e-04
# Epoch 193/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - learning_rate: 1.6055e-04
# Epoch 194/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - learning_rate: 1.5894e-04
# Epoch 195/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - learning_rate: 1.5735e-04
# Epoch 196/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - learning_rate: 1.5578e-04
# Epoch 197/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0558 - mean_squared_error: 0.0558 - learning_rate: 1.5422e-04
# Epoch 198/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0203 - mean_squared_error: 0.0203 - learning_rate: 1.5268e-04
# Epoch 199/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - learning_rate: 1.5115e-04
# Epoch 200/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5889 - mean_squared_error: 0.5889 - val_loss: 0.7861 - val_mean_squared_error: 0.7861 - learning_rate: 1.4964e-04
# Epoch 201/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4164 - mean_squared_error: 0.4164 - learning_rate: 1.4815e-04
# Epoch 202/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0438 - mean_squared_error: 0.0438 - learning_rate: 1.4666e-04
# Epoch 203/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - learning_rate: 1.4520e-04
# Epoch 204/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - learning_rate: 1.4374e-04
# Epoch 205/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - learning_rate: 1.4231e-04
# Epoch 206/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - learning_rate: 1.4088e-04
# Epoch 207/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - learning_rate: 1.3948e-04
# Epoch 208/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - learning_rate: 1.3808e-04
# Epoch 209/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - learning_rate: 1.3670e-04
# Epoch 210/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - learning_rate: 1.3533e-04
# Epoch 211/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - learning_rate: 1.3398e-04
# Epoch 212/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - learning_rate: 1.3264e-04
# Epoch 213/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - learning_rate: 1.3131e-04
# Epoch 214/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - learning_rate: 1.3000e-04
# Epoch 215/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0381 - mean_squared_error: 0.0381 - learning_rate: 1.2870e-04
# Epoch 216/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4204 - mean_squared_error: 0.4204 - learning_rate: 1.2741e-04
# Epoch 217/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0815 - mean_squared_error: 0.0815 - learning_rate: 1.2614e-04
# Epoch 218/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - learning_rate: 1.2488e-04
# Epoch 219/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - learning_rate: 1.2363e-04
# Epoch 220/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - learning_rate: 1.2239e-04
# Epoch 221/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - learning_rate: 1.2117e-04
# Epoch 222/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - learning_rate: 1.1996e-04
# Epoch 223/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - learning_rate: 1.1876e-04
# Epoch 224/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - learning_rate: 1.1757e-04
# Epoch 225/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - learning_rate: 1.1639e-04
# Epoch 226/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - learning_rate: 1.1523e-04
# Epoch 227/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - learning_rate: 1.1408e-04
# Epoch 228/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - learning_rate: 1.1294e-04
# Epoch 229/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - learning_rate: 1.1181e-04
# Epoch 230/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3029 - mean_squared_error: 0.3029 - val_loss: 0.0469 - val_mean_squared_error: 0.0469 - learning_rate: 1.1069e-04
# Epoch 231/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0464 - mean_squared_error: 0.0464 - learning_rate: 1.0958e-04
# Epoch 232/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - learning_rate: 1.0849e-04
# Epoch 233/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - learning_rate: 1.0740e-04
# Epoch 234/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - learning_rate: 1.0633e-04
# Epoch 235/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - learning_rate: 1.0526e-04
# Epoch 236/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - learning_rate: 1.0421e-04
# Epoch 237/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - learning_rate: 1.0317e-04
# Epoch 238/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 1.0214e-04
# Epoch 239/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - learning_rate: 1.0112e-04
# Epoch 240/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1171 - mean_squared_error: 0.1171 - val_loss: 0.2242 - val_mean_squared_error: 0.2242 - learning_rate: 1.0011e-04
# Epoch 241/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3287 - mean_squared_error: 0.3287 - learning_rate: 9.9105e-05
# Epoch 242/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - learning_rate: 9.8114e-05
# Epoch 243/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - learning_rate: 9.7133e-05
# Epoch 244/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - learning_rate: 9.6161e-05
# Epoch 245/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 9.5200e-05
# Epoch 246/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 9.4248e-05
# Epoch 247/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - learning_rate: 9.3305e-05
# Epoch 248/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - learning_rate: 9.2372e-05
# Epoch 249/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - learning_rate: 9.1448e-05
# Epoch 250/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - learning_rate: 9.0534e-05
# Epoch 251/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - learning_rate: 8.9629e-05
# Epoch 252/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - learning_rate: 8.8732e-05
# Epoch 253/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - learning_rate: 8.7845e-05
# Epoch 254/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - learning_rate: 8.6967e-05
# Epoch 255/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - learning_rate: 8.6097e-05
# Epoch 256/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - learning_rate: 8.5236e-05
# Epoch 257/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mean_squared_error: 0.0485 - learning_rate: 8.4384e-05
# Epoch 258/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - learning_rate: 8.3540e-05
# Epoch 259/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - learning_rate: 8.2704e-05
# Epoch 260/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - learning_rate: 8.1877e-05
# Epoch 261/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - learning_rate: 8.1059e-05
# Epoch 262/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0423 - mean_squared_error: 0.0423 - learning_rate: 8.0248e-05
# Epoch 263/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0794 - mean_squared_error: 0.0794 - learning_rate: 7.9445e-05
# Epoch 264/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - learning_rate: 7.8651e-05
# Epoch 265/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - learning_rate: 7.7865e-05
# Epoch 266/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - learning_rate: 7.7086e-05
# Epoch 267/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - learning_rate: 7.6315e-05
# Epoch 268/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8690e-04 - mean_squared_error: 8.8689e-04 - learning_rate: 7.5552e-05
# Epoch 269/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7115e-04 - mean_squared_error: 9.7115e-04 - learning_rate: 7.4796e-05
# Epoch 270/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9471e-04 - mean_squared_error: 7.9471e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - learning_rate: 7.4048e-05
# Epoch 271/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - learning_rate: 7.3308e-05
# Epoch 272/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 7.2575e-05
# Epoch 273/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 7.1849e-05
# Epoch 274/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 7.1131e-05
# Epoch 275/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - learning_rate: 7.0419e-05
# Epoch 276/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - learning_rate: 6.9715e-05
# Epoch 277/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - learning_rate: 6.9018e-05
# Epoch 278/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - learning_rate: 6.8328e-05
# Epoch 279/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - learning_rate: 6.7644e-05
# Epoch 280/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - learning_rate: 6.6968e-05
# Epoch 281/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - learning_rate: 6.6298e-05
# Epoch 282/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - learning_rate: 6.5635e-05
# Epoch 283/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - learning_rate: 6.4979e-05
# Epoch 284/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - learning_rate: 6.4329e-05
# Epoch 285/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - learning_rate: 6.3686e-05
# Epoch 286/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0712 - mean_squared_error: 0.0712 - learning_rate: 6.3049e-05
# Epoch 287/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0735 - mean_squared_error: 0.0735 - learning_rate: 6.2419e-05
# Epoch 288/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - learning_rate: 6.1794e-05
# Epoch 289/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - learning_rate: 6.1176e-05
# Epoch 290/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - learning_rate: 6.0565e-05
# Epoch 291/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - learning_rate: 5.9959e-05
# Epoch 292/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - learning_rate: 5.9359e-05
# Epoch 293/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - learning_rate: 5.8766e-05
# Epoch 294/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - learning_rate: 5.8178e-05
# Epoch 295/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - learning_rate: 5.7596e-05
# Epoch 296/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - learning_rate: 5.7020e-05
# Epoch 297/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 5.6450e-05
# Epoch 298/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - learning_rate: 5.5886e-05
# Epoch 299/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - learning_rate: 5.5327e-05
# Epoch 300/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - learning_rate: 5.4774e-05
# Epoch 301/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - learning_rate: 5.4226e-05
# Epoch 302/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - learning_rate: 5.3684e-05
# Epoch 303/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2136e-04 - mean_squared_error: 8.2136e-04 - learning_rate: 5.3147e-05
# Epoch 304/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0941e-04 - mean_squared_error: 6.0941e-04 - learning_rate: 5.2615e-05
# Epoch 305/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8223e-04 - mean_squared_error: 8.8222e-04 - learning_rate: 5.2089e-05
# Epoch 306/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9024e-04 - mean_squared_error: 8.9024e-04 - learning_rate: 5.1568e-05
# Epoch 307/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6074e-04 - mean_squared_error: 5.6073e-04 - learning_rate: 5.1053e-05
# Epoch 308/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1576e-04 - mean_squared_error: 8.1576e-04 - learning_rate: 5.0542e-05
# Epoch 309/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5383e-04 - mean_squared_error: 7.5383e-04 - learning_rate: 5.0037e-05
# Epoch 310/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 8.2878e-04 - val_mean_squared_error: 8.2877e-04 - learning_rate: 4.9536e-05
# Epoch 311/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - learning_rate: 4.9041e-05
# Epoch 312/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5357e-04 - mean_squared_error: 9.5357e-04 - learning_rate: 4.8550e-05
# Epoch 313/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9594e-04 - mean_squared_error: 9.9594e-04 - learning_rate: 4.8065e-05
# Epoch 314/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - learning_rate: 4.7584e-05
# Epoch 315/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - learning_rate: 4.7108e-05
# Epoch 316/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 4.6637e-05
# Epoch 317/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - learning_rate: 4.6171e-05
# Epoch 318/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - learning_rate: 4.5709e-05
# Epoch 319/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - learning_rate: 4.5252e-05
# Epoch 320/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - learning_rate: 4.4800e-05
# Epoch 321/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - learning_rate: 4.4352e-05
# Epoch 322/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 4.3908e-05
# Epoch 323/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1306e-04 - mean_squared_error: 7.1306e-04 - learning_rate: 4.3469e-05
# Epoch 324/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5323e-04 - mean_squared_error: 8.5323e-04 - learning_rate: 4.3034e-05
# Epoch 325/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - learning_rate: 4.2604e-05
# Epoch 326/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - learning_rate: 4.2178e-05
# Epoch 327/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - learning_rate: 4.1756e-05
# Epoch 328/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6946e-04 - mean_squared_error: 9.6946e-04 - learning_rate: 4.1339e-05
# Epoch 329/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - learning_rate: 4.0925e-05
# Epoch 330/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - learning_rate: 4.0516e-05
# Epoch 331/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - learning_rate: 4.0111e-05
# Epoch 332/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - learning_rate: 3.9710e-05
# Epoch 333/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - learning_rate: 3.9313e-05
# Epoch 334/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - learning_rate: 3.8920e-05
# Epoch 335/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - learning_rate: 3.8530e-05
# Epoch 336/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2480e-04 - mean_squared_error: 9.2480e-04 - learning_rate: 3.8145e-05
# Epoch 337/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - learning_rate: 3.7764e-05
# Epoch 338/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - learning_rate: 3.7386e-05
# Epoch 339/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - learning_rate: 3.7012e-05
# Epoch 340/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - learning_rate: 3.6642e-05
# Epoch 341/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 3.6276e-05
# Epoch 342/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - learning_rate: 3.5913e-05
# Epoch 343/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - learning_rate: 3.5554e-05
# Epoch 344/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - learning_rate: 3.5198e-05
# Epoch 345/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - learning_rate: 3.4846e-05
# Epoch 346/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - learning_rate: 3.4498e-05
# Epoch 347/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - learning_rate: 3.4153e-05
# Epoch 348/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2764e-04 - mean_squared_error: 6.2764e-04 - learning_rate: 3.3811e-05
# Epoch 349/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - learning_rate: 3.3473e-05
# Epoch 350/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2388e-04 - mean_squared_error: 9.2387e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - learning_rate: 3.3138e-05
# Epoch 351/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1911e-04 - mean_squared_error: 9.1910e-04 - learning_rate: 3.2807e-05
# Epoch 352/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - learning_rate: 3.2479e-05
# Epoch 353/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - learning_rate: 3.2154e-05
# Epoch 354/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - learning_rate: 3.1833e-05
# Epoch 355/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - learning_rate: 3.1514e-05
# Epoch 356/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - learning_rate: 3.1199e-05
# Epoch 357/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - learning_rate: 3.0887e-05
# Epoch 358/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - learning_rate: 3.0578e-05
# Epoch 359/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - learning_rate: 3.0272e-05
# Epoch 360/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 6.7131e-04 - val_mean_squared_error: 6.7131e-04 - learning_rate: 2.9970e-05
# Epoch 361/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9765e-04 - mean_squared_error: 5.9765e-04 - learning_rate: 2.9670e-05
# Epoch 362/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0152e-04 - mean_squared_error: 5.0151e-04 - learning_rate: 2.9373e-05
# Epoch 363/10000
# ...
# Epoch 8904/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5282e-05 - mean_squared_error: 5.5280e-05 - learning_rate: 1.3448e-08
# Epoch 8905/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6364e-05 - mean_squared_error: 6.6361e-05 - learning_rate: 1.3446e-08
# Epoch 8906/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7661e-05 - mean_squared_error: 5.7658e-05 - learning_rate: 1.3445e-08
# Epoch 8907/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8920e-05 - mean_squared_error: 5.8917e-05 - learning_rate: 1.3443e-08
# Epoch 8908/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2281e-05 - mean_squared_error: 5.2279e-05 - learning_rate: 1.3442e-08
# Epoch 8909/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9562e-05 - mean_squared_error: 5.9559e-05 - learning_rate: 1.3440e-08
# Epoch 8910/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1051e-05 - mean_squared_error: 5.1048e-05 - val_loss: 7.9843e-05 - val_mean_squared_error: 7.9841e-05 - learning_rate: 1.3439e-08
# Epoch 8911/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5207e-05 - mean_squared_error: 7.5205e-05 - learning_rate: 1.3437e-08
# Epoch 8912/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6899e-05 - mean_squared_error: 5.6896e-05 - learning_rate: 1.3436e-08
# Epoch 8913/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0499e-05 - mean_squared_error: 6.0497e-05 - learning_rate: 1.3434e-08
# Epoch 8914/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8676e-05 - mean_squared_error: 5.8674e-05 - learning_rate: 1.3433e-08
# Epoch 8915/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3233e-05 - mean_squared_error: 6.3230e-05 - learning_rate: 1.3431e-08
# Epoch 8916/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1333e-05 - mean_squared_error: 5.1331e-05 - learning_rate: 1.3430e-08
# Epoch 8917/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7073e-05 - mean_squared_error: 5.7071e-05 - learning_rate: 1.3428e-08
# Epoch 8918/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7282e-05 - mean_squared_error: 5.7279e-05 - learning_rate: 1.3427e-08
# Epoch 8919/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6283e-05 - mean_squared_error: 5.6280e-05 - learning_rate: 1.3425e-08
# Epoch 8920/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5470e-05 - mean_squared_error: 5.5468e-05 - val_loss: 7.9417e-05 - val_mean_squared_error: 7.9414e-05 - learning_rate: 1.3424e-08
# Epoch 8921/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6030e-05 - mean_squared_error: 6.6027e-05 - learning_rate: 1.3422e-08
# Epoch 8922/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6406e-05 - mean_squared_error: 6.6403e-05 - learning_rate: 1.3421e-08
# Epoch 8923/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9276e-05 - mean_squared_error: 7.9274e-05 - learning_rate: 1.3419e-08
# Epoch 8924/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2481e-05 - mean_squared_error: 5.2479e-05 - learning_rate: 1.3418e-08
# Epoch 8925/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1830e-05 - mean_squared_error: 6.1828e-05 - learning_rate: 1.3416e-08
# Epoch 8926/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1835e-05 - mean_squared_error: 7.1832e-05 - learning_rate: 1.3415e-08
# Epoch 8927/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9095e-05 - mean_squared_error: 4.9093e-05 - learning_rate: 1.3413e-08
# Epoch 8928/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2267e-05 - mean_squared_error: 6.2265e-05 - learning_rate: 1.3412e-08
# Epoch 8929/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2846e-05 - mean_squared_error: 5.2844e-05 - learning_rate: 1.3410e-08
# Epoch 8930/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6106e-05 - mean_squared_error: 5.6104e-05 - val_loss: 7.9620e-05 - val_mean_squared_error: 7.9617e-05 - learning_rate: 1.3409e-08
# Epoch 8931/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1702e-05 - mean_squared_error: 7.1699e-05 - learning_rate: 1.3407e-08
# Epoch 8932/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1770e-05 - mean_squared_error: 5.1767e-05 - learning_rate: 1.3406e-08
# Epoch 8933/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2253e-05 - mean_squared_error: 6.2251e-05 - learning_rate: 1.3404e-08
# Epoch 8934/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4882e-05 - mean_squared_error: 5.4880e-05 - learning_rate: 1.3403e-08
# Epoch 8935/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7261e-05 - mean_squared_error: 5.7259e-05 - learning_rate: 1.3401e-08
# Epoch 8936/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1847e-05 - mean_squared_error: 5.1845e-05 - learning_rate: 1.3400e-08
# Epoch 8937/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2432e-05 - mean_squared_error: 7.2430e-05 - learning_rate: 1.3398e-08
# Epoch 8938/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6953e-05 - mean_squared_error: 7.6951e-05 - learning_rate: 1.3397e-08
# Epoch 8939/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8112e-05 - mean_squared_error: 6.8109e-05 - learning_rate: 1.3395e-08
# Epoch 8940/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0855e-05 - mean_squared_error: 6.0853e-05 - val_loss: 7.9633e-05 - val_mean_squared_error: 7.9630e-05 - learning_rate: 1.3394e-08
# Epoch 8941/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5458e-05 - mean_squared_error: 6.5456e-05 - learning_rate: 1.3392e-08
# Epoch 8942/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1385e-05 - mean_squared_error: 8.1383e-05 - learning_rate: 1.3391e-08
# Epoch 8943/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7796e-05 - mean_squared_error: 5.7794e-05 - learning_rate: 1.3389e-08
# Epoch 8944/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5208e-05 - mean_squared_error: 5.5206e-05 - learning_rate: 1.3388e-08
# Epoch 8945/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2868e-05 - mean_squared_error: 5.2865e-05 - learning_rate: 1.3386e-08
# Epoch 8946/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1897e-05 - mean_squared_error: 6.1894e-05 - learning_rate: 1.3385e-08
# Epoch 8947/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9694e-05 - mean_squared_error: 5.9692e-05 - learning_rate: 1.3383e-08
# Epoch 8948/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6631e-05 - mean_squared_error: 5.6628e-05 - learning_rate: 1.3382e-08
# Epoch 8949/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8245e-05 - mean_squared_error: 5.8243e-05 - learning_rate: 1.3380e-08
# Epoch 8950/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1123e-05 - mean_squared_error: 6.1121e-05 - val_loss: 8.0157e-05 - val_mean_squared_error: 8.0155e-05 - learning_rate: 1.3379e-08
# Epoch 8951/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1043e-05 - mean_squared_error: 6.1041e-05 - learning_rate: 1.3377e-08
# Epoch 8952/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6351e-05 - mean_squared_error: 5.6348e-05 - learning_rate: 1.3376e-08
# Epoch 8953/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5364e-05 - mean_squared_error: 6.5362e-05 - learning_rate: 1.3374e-08
# Epoch 8954/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0520e-05 - mean_squared_error: 6.0517e-05 - learning_rate: 1.3373e-08
# Epoch 8955/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4910e-05 - mean_squared_error: 5.4907e-05 - learning_rate: 1.3371e-08
# Epoch 8956/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0967e-05 - mean_squared_error: 6.0965e-05 - learning_rate: 1.3370e-08
# Epoch 8957/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7459e-05 - mean_squared_error: 7.7456e-05 - learning_rate: 1.3368e-08
# Epoch 8958/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3177e-05 - mean_squared_error: 6.3175e-05 - learning_rate: 1.3367e-08
# Epoch 8959/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8489e-05 - mean_squared_error: 5.8487e-05 - learning_rate: 1.3365e-08
# Epoch 8960/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5503e-05 - mean_squared_error: 6.5500e-05 - val_loss: 7.9533e-05 - val_mean_squared_error: 7.9531e-05 - learning_rate: 1.3364e-08
# Epoch 8961/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0381e-05 - mean_squared_error: 6.0378e-05 - learning_rate: 1.3362e-08
# Epoch 8962/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1583e-05 - mean_squared_error: 6.1581e-05 - learning_rate: 1.3361e-08
# Epoch 8963/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1442e-05 - mean_squared_error: 6.1439e-05 - learning_rate: 1.3360e-08
# Epoch 8964/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2316e-05 - mean_squared_error: 5.2314e-05 - learning_rate: 1.3358e-08
# Epoch 8965/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8529e-05 - mean_squared_error: 5.8526e-05 - learning_rate: 1.3357e-08
# Epoch 8966/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0741e-05 - mean_squared_error: 6.0739e-05 - learning_rate: 1.3355e-08
# Epoch 8967/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1623e-05 - mean_squared_error: 6.1621e-05 - learning_rate: 1.3354e-08
# Epoch 8968/10000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9880e-05 - mean_squared_error: 5.9878e-05 - learning_rate: 1.3352e-08
# Epoch 8969/10000
# 28/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8897e-05 - mean_squared_error: 5.8894e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[141], line 76
#      73 lr_scheduler = LearningRateScheduler(scheduler)
#      75 # Train the model
# ---> 76 history = model.fit([X_train_params, X_train_pod], y_train,
#      77                     epochs=10000,
#      78                     batch_size=data_processor_I.config['BATCH_SIZE']//150,
#      79                     validation_data=([X_test_params, X_test_pod], y_test),
#      80                     validation_freq=10,
#      81                     callbacks=[lr_scheduler])
#      83 # Save the model for each fold
#      84 model.save(f'./models/model_euler_mf.keras')
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/anaconda3/envs/fenics/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Save the model for each fold
model.save(f'./models/model_euler_mf.keras')

# %%
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed

plt.plot(np.arange(10000), history.history['loss'], 'b-', label='Training loss', linewidth=2)
plt.plot(10 * np.arange(1000), history.history['val_loss'], 'r--', label='Validation loss', linewidth=2)
plt.yscale('log')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(fontsize=12)
plt.title('Training and Validation Loss', fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# # Multilevel NN

# %% [markdown]
# Let us now train a simplified NN compared to the fine models that takes as input parameter the output of the coarse model ( One Out of Three elements of the coarse solution )

# %% [markdown]
# First we have to create a dataset of the coarse sol for all the data we have

# %%
coarse_y_train = []
coarse_y_test = []
for x in X_train:  
    coarse_y_train.append(coarse_model(x)[0:150:3])
for x in X_test:
    coarse_y_test.append(coarse_model(x)[0:150:3])

# Concatenate input parameters and coarse solutions
X_train_combined = np.concatenate((X_train, coarse_y_train), axis=1)
X_test_combined = np.concatenate((X_test, coarse_y_test), axis=1)

# %% [markdown]
# ### Single Layer NN - One out of 3

# %% [markdown]
# Initialize the weights matrix as a the linear interpolation between the subsample of the solutions

# %%
# Define the initial weights matrix 
w = np.zeros((50,150))
for i in range(50):
    for j in range(150):
        if j == 3*i:
            w[i,j]=1
        if j == 3*i-1 or j == 3*i+1 and j<150:
            w[i,j]=2/3
        if j == 3*i-2 or j == 3*i +2 and j<150 :
            w[i,j]=1/3
w[49,149] = 1
w[49,148] = 1
weight_matrix = [ np.vstack([np.zeros((3,150)),w ] ), np.zeros(150) ]

# %% [markdown]
# Train or load the Neural Network

# %%
Training = False

num_samples = 640
num_parameters = 3
num_coarse_values = 50



# Define the neural network model
model_LF_NN_oo3 = Sequential([
        Dense(150,input_shape=(num_parameters + num_coarse_values,),activation='linear')
       ])

# Set the initial weights for the dense layer
model_LF_NN_oo3.layers[0].set_weights(weight_matrix)

if Training: 
       
       # Define the optimizer with an initial learning rate
       initial_learning_rate = 1e-3
       optimizer = Adam(learning_rate=initial_learning_rate) 

       # Compile the model with the optimizer
       model_LF_NN_oo3.compile(optimizer=optimizer, loss='mean_squared_error')

       # Define a learning rate scheduler
       learning_rate_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=200, min_lr=2e-6)

       # Concatenate input parameters and coarse solutions
       X_train_combined = np.concatenate((X_train, coarse_y_train), axis=1)
       X_test_combined = np.concatenate((X_test, coarse_y_test), axis=1)
    

       # Train the model
       history = model_LF_NN_oo3.fit(X_train_combined, y_train, epochs = 3000, batch_size=64, validation_data= (X_test_combined, y_test), callbacks=learning_rate_scheduler)

       model_LF_NN_oo3.save('./models/model_LF_NN_oo3.keras')

       # Plot the errors 
       plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
       tot_train = len(history.history['loss'])
       tot_valid = len(history.history['val_loss']) 
       valid_freq = int(tot_train / tot_valid)
       plt.plot(np.arange(tot_train), history.history['loss'], 'b-', label='Training loss', linewidth=2)
       plt.plot(valid_freq * np.arange(tot_valid), history.history['val_loss'], 'r--', label='Validation loss', linewidth=2)
       plt.yscale('log')
       plt.xlabel('Epochs', fontsize=14)
       plt.ylabel('Loss', fontsize=14)
       plt.legend(fontsize=12)
       plt.title('Training and Validation Loss', fontsize=16)
       plt.grid(True)
       plt.show()


# Load the model
model_LF_NN_oo3 = load_model('./models/model_LF_NN_oo3.keras')
# Out:
# /Users/lucacaroselli/miniconda3/envs/bima/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Save directly the weights and bias to use directly in computing the soliution making the coarse model faster. This is possibile since we are using a single layer (0 Hidden NN) with linear activation function.
#
# Consequently the result is W*x + b where:
#
# W is the weight matrix of the NN
# b in the bias vector
# X is the coarse solution obtained with Euler Forward

# %%
np.save('./models/weights_NN_oo32.npy', model_LF_NN_oo3.layers[0].get_weights()[0])
np.save('./models/bias_NN_oo32.npy', model_LF_NN_oo3.layers[0].get_weights()[1])

# %% [markdown]
# Load the model
# the normal way ( we simply use the pre-trained NN )
# the optimized way where the weights and bias terms are directly used as matrix multiplication

# %%
# Import the function coarse_model
sys.path.append('../../tests/Xaccelerometer_geometric/models')
from coarse_model import *

model_lf_oo3 = create_model_LF_NN_oo3(model_LF_NN_oo3)
model_lf_oo3_opt = create_model_LF_NN_oo3_opt()

# %%
ratio = []
for index, x in enumerate(x_true):
    print('The parameters used are:' , x)
    res = model_lf_oo3_opt(x)
    x = np.linspace(0,150,150)
    plt.plot(x, res)
    plt.plot(x,y_true[index], color = 'r', alpha = 0.8)
    plt.legend(['Coarse Model', 'Fine Model'])
    plt.show()
    ratio.append(  np.linalg.norm((res - y_true[index]), ord=1)  / np.linalg.norm(( y_true[index]), ord=1) )

#plt.plot(y_true[-1]-res)
#plt.show()
print('Mean absolute percentage error for the simulations are:\n', np.array(ratio) )
# Out:
# The parameters used are: [ 0.230536 -0.068871 30.351452]
# The parameters used are: [ 4.5057900e-01 -4.4200000e-04  2.9471304e+01]
# The parameters used are: [ 0.150782 -0.061468 30.962383]
# The parameters used are: [ 2.6249600e-01 -2.7814000e-02  2.9626475e+01]
# The parameters used are: [ 0.464787 -0.34692  29.295773]
# Mean absolute percentage error for the simulations are:
#  [0.00135559 0.00720274 0.00127222 0.0018041  0.00052355]

# %% [markdown]
# ### Evaluate the speed of the new models compared to the fine one

# %%
# Initialize and load model
model_I = NN_Model()
model_I.load_model(data_processor_I.config['MODEL_PATH'])

# Define forward function
forward_model = create_forward_model_function(data_processor_I, model_I)

# %%
import numpy as np
import tensorflow as tf
import timeit
 
# Define parameters x 
X = np.random.uniform(low=[0.1, -0.5, 29.0], high=[0.5, 0.5, 31.0], size=(10000, 3))

time = data_processor_I.time
X_rep = np.repeat(X, len(time), axis=0)
time_repeated = np.tile(time, len(X_rep) // len(time))
X_rep = np.column_stack((X_rep, time_repeated))
X_new = data_processor_I.scaler.transform(X_rep)
 
# Compute the coarse model predictions 
start_0 = timeit.default_timer() 
coarse_predictions = [coarse_model(X[i,:]) for i in range(10000)]
end_0 = timeit.default_timer()
 
 
# Measure time for coarse model predictions
start_time = timeit.default_timer()
# Use the one layer model to predict in one go rather than in a loop
res_coarse_oo2 = [model_lf_oo3(X[i,:]) for i in range(10000)]
end_time = timeit.default_timer()

# Measure time for coarse model predictions
start_time1 = timeit.default_timer()
# Use the one layer model to predict in one go rather than in a loop
res_coarse_oo3 = [model_lf_oo3_opt(X[i,:]) for i in range(10000)]
end_time1 = timeit.default_timer()
 
# Use the 6 layer model
start_time2 = timeit.default_timer()
res_fine = [forward_model(X[i,:]) for i in range(10000)]
end_time2 = timeit.default_timer()
 
print('Time Euler', (end_0-start_0)/10000)
print('Time NN one out of 3', (end_time-start_time)/10000)
print('Time NN one out of 3 Optimized', (end_time1-start_time1)/10000)
print('Time Fine', (end_time2 - start_time2)/10000)
print('\nThe speedup coefficient fine/Euler is:',(end_time2 - start_time2)/(end_0-start_0) )
print('\nThe speedup coefficient fine/oo3 is:', (end_time2 - start_time2)/(end_time-start_time))
print('\nThe speedup coefficient fine/oo3_opt is:', (end_time2 - start_time2)/(end_time1-start_time1))
print('\nThe speedup coefficient oo3/oo3_opt is:', (end_time - start_time)/(end_time1-start_time1))
# Out:
# Time Euler 7.077479199506343e-06
# Time NN one out of 3 0.0004859145125024952
# Time NN one out of 3 Optimized 1.4227050001500175e-05
# Time Fine 0.0026435135750012707
#
# The speedup coefficient fine/Euler is: 373.51061027288597
#
# The speedup coefficient fine/oo3 is: 5.440285290898151
#
# The speedup coefficient fine/oo3_opt is: 185.8089747855335
#
# The speedup coefficient oo3/oo3_opt is: 34.15427038291549

# %% [markdown]
# #### Evaluate the accuracy of each model

# %%
X_test = data_processor_I.X_test
y_test = data_processor_I.y_test

# Initialize the vector of MSE for each prediciton 
Euler_mse = []
NN_mse = []
fine_mse = []


for i in range(len(X_test)):
    Euler_mse.append(np.mean((coarse_model(X_test[i,:])-y_test[i,:])**2))
    NN_mse.append(np.mean((model_lf_oo3_opt(X_test[i,:])-y_test[i,:])**2))
    fine_mse.append(np.mean((forward_model(X_test[i,:])-y_test[i,:])**2))

print('Euler MSE:', np.mean(Euler_mse))
print('NN MSE:   ', np.mean(NN_mse))
print('Fine MSE: ', np.mean(fine_mse))
# Out:
# Euler MSE: 0.21056394617396057
# NN MSE:    0.0010493314239123836
# Fine MSE:  0.0002919252155230866

# %% [markdown]
# #### Evaluate the sensitivity of the model with respect to the parameters
#
# We will now compare the errors of the two coarse surrogate models compared to the fine model.
# The goal of this section is to highlight which parameter variation could most affect the error in the prediction using the coarse models.
# We note that this operation whould be preferably done with the true solution

# %% [markdown]
# fixing thickness

# %%
import seaborn as sns

# create a grid fixing the thickness
n = 15
th = 30.
overetch = np.linspace(0.1, 0.5, n)
offset = np.linspace(-0.5, 0.43, n)


# initalize the error matrix
err_euler = np.zeros((n,n))
err_NN = np.zeros((n,n))

for i, oe in enumerate(overetch):
    for j , of in enumerate(offset):
        x = [oe, of, th]
        err_euler[i,j] = np.mean((coarse_model(x)-forward_model(x))**2)
        err_NN[i,j] = np.mean((model_lf_oo3_opt(x)-forward_model(x))**2)


sns.heatmap(err_euler, cmap='viridis')
plt.yticks(ticks=np.arange(len(overetch)) + 0.5, labels=np.round(overetch,2), rotation = 'vertical')  # Adjust 0.5 offset if needed
plt.xticks(ticks=np.arange(len(offset)) + 0.5, labels=np.round(offset,2), rotation = 'horizontal')  
plt.xlabel('Overetch')
plt.ylabel('Offset')
plt.show()

sns.heatmap(err_NN, cmap='viridis')
plt.xticks(ticks=np.arange(len(overetch)) + 0.5, labels=np.round(overetch,2), rotation = 'vertical')  
plt.yticks(ticks=np.arange(len(offset)) + 0.5, labels=np.round(offset,2), rotation = 'horizontal')  
plt.xlabel('Overetch')
plt.ylabel('Offset')
plt.show()


x_bad = [overetch[0], offset[n-1], 30.]
print(x_bad)
plt.plot(forward_model(x_bad))
plt.plot(coarse_model(x_bad))
plt.plot(model_lf_oo3_opt(x_bad))
plt.legend(['Fine model', 'Euler', 'NN'])
plt.show
# Out:
# [0.1, 0.43, 30.0]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_t, y_t = X_values[11], y_values[11]

plt.plot(y_t, color = 'red')
plt.plot(coarse_model(x_t), color = 'orange')
plt.plot(model_lf_oo3_opt(x_t))
plt.legend(['True Solution', 'Euler', 'Coarse NN'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# fixing overetch

# %%
# create a grid fixing the thickness
n = 15
oe = 0.3
thickness = np.linspace(29., 31., n)
offset = np.linspace(-0.5, 0.5, n)


# initalize the error matrix
err_euler = np.zeros((n,n))
err_NN = np.zeros((n,n))

for i, th in enumerate(thickness):
    for j , of in enumerate(offset):
        x = [oe, of, th]
        err_euler[i,j] = np.mean((coarse_model(x)-forward_model(x))**2)
        err_NN[i,j] = np.mean((model_lf_oo3_opt(x)-forward_model(x))**2)


sns.heatmap(err_euler, cmap='viridis')
plt.yticks(ticks=np.arange(len(thickness)) + 0.5, labels=np.round(thickness,2), rotation = 'horizontal')  # Adjust 0.5 offset if needed
plt.xticks(ticks=np.arange(len(offset)) + 0.5, labels=np.round(offset,2), rotation = 'vertical')  
plt.title('MSE Euler, fixed Overetch = 0.3')
plt.xlabel('Offset')
plt.ylabel('Thickness')
plt.show()

sns.heatmap(err_NN, cmap='viridis')
plt.yticks(ticks=np.arange(len(thickness)) + 0.5, labels=np.round(thickness,2), rotation = 'horizontal')  # Adjust 0.5 offset if needed
plt.xticks(ticks=np.arange(len(offset)) + 0.5, labels=np.round(offset,2), rotation = 'vertical')  
plt.title('MSE NN, fixed Overetch = 0.3')
plt.xlabel('Offset')
plt.ylabel('Thickness')
plt.show()

# %% [markdown]
# fixing Offset

# %%
# create a grid fixing the thickness
n = 15
of = 0.
thickness = np.linspace(29., 31., n)
overetch = np.linspace(0.1, 0.5, n)


# initalize the error matrix
err_euler = np.zeros((n,n))
err_NN = np.zeros((n,n))

for i, th in enumerate(thickness):
    for j , oe in enumerate(overetch):
        x = [oe, of, th]
        err_euler[i,j] = np.mean((coarse_model(x)-forward_model(x))**2)
        err_NN[i,j] = np.mean((model_lf_oo3_opt(x)-forward_model(x))**2)


sns.heatmap(err_euler, cmap='viridis')
plt.yticks(ticks=np.arange(len(thickness)) + 0.5, labels=np.round(thickness,2), rotation = 'horizontal')  # Adjust 0.5 offset if needed
plt.xticks(ticks=np.arange(len(overetch)) + 0.5, labels=np.round(overetch,2), rotation = 'vertical')  
plt.xlabel('Overetch')
plt.ylabel('Thickness')
plt.show()

sns.heatmap(err_NN, cmap='viridis')
plt.yticks(ticks=np.arange(len(thickness)) + 0.5, labels=np.round(thickness,2), rotation = 'horizontal')  # Adjust 0.5 offset if needed
plt.xticks(ticks=np.arange(len(overetch)) + 0.5, labels=np.round(overetch,2), rotation = 'vertical')  
plt.xlabel('Overetch')
plt.ylabel('Thickness')
plt.show()
